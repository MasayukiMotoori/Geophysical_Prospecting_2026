# %%
import numpy as np
import pandas as pd
from scipy import optimize
from scipy.constants import mu_0, epsilon_0
from scipy import fftpack
from scipy import sparse
from scipy.special import factorial
from scipy.signal import butter, filtfilt
from scipy.interpolate import interp1d, CubicSpline, BSpline
from scipy.sparse import csr_matrix, csc_matrix
import csv
from scipy.special import roots_legendre, eval_legendre
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy.linalg import lu_factor, lu_solve
from scipy import signal
import ipywidgets
import discretize
import  os
import json
from PIL import Image
import seaborn as sns
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
import ipywidgets as widgets
import string
eps = np.finfo(float).eps

# %%
import empymod
from masa_utils import PsuedoLog
from masa_utils import Pelton_res_f, DDR_f
from masa_utils import InducedPolarizationSimulation 
from masa_utils import Optimization 
from masa_utils import empymod_IP_simulation
from masa_utils import TEM_Signal_Process

# %% [markdown]
# Simulatin and synthetic study on deep sea hydrothermal deposits explortaion using WISTEM (K. Nakayama and A. Saito, 2016) (K.Nakayama M. Motoori and A. Saito,2019). On-Time: 200msec ramp time: 200usec Transmitter Loop: 3.5m Square Loop Receiver Loop: Coincident-type Number of Turn: 5 3.5m rectangular loop has equivalent area for 2.0m circular loop.

# %%
# --- helper to render LaTeX labels (robust method) ---
def math_label(tex, width="160px"):
    out = widgets.Output(layout=widgets.Layout(width=width))
    with out:
        display(Math(tex))
    return out
def sci_latex(v, prec=2):
    s = f"{v:.{prec}e}"          # e.g. '3.00e-03'
    mant, exp = s.split('e')
    exp = int(exp)

    if float(mant) == 0:
        return "0"

    if exp in [0, -1]:
        return f"{float(mant)*10**exp:.{prec}f}"
    else:
        return rf"{mant}\cdot 10^{{{exp}}}"


def fmt(v, prec=2, latex=False, wrap=False):
    # blank for None or empty string
    if v is None or v == "":
        return ""

    # if already string → return as-is
    if isinstance(v, str):
        return v

    try:
        s = sci_latex(v, prec=prec)

        if latex:
            if wrap:
                return rf"$${s}$$"   # display math
            else:
                return rf"${s}$"     # inline math
        else:
            return s

    except:
        return ""

# %%
plt.style.use('00_figures.mplstyle')
textwidth = 5.60739

# %%
rmp_time=200e-6

smp_freq=50e3 #200e3

# %%
tx_side = 3.5
tx_radius = (tx_side)/(np.sqrt(np.pi))
tx_circumeference = 2*np.pi*tx_radius
tx_surface = np.pi*tx_radius**2
n_turns = 5
tx_depth = 0
print(f"Transmitter radius: {tx_radius}")
# Out:
# Transmitter radius: 1.9746635424171473

# %%
tstrt, tend = 1e-4, 1e-2
logstep = 1/15
WISTEM_SP_sim = TEM_Signal_Process(
    # base_freq=base_freq,
    # on_time=on_time, 
    rmp_time=rmp_time, 
    rec_time=tend, 
    smp_freq=smp_freq
)

# %%
times_sim = WISTEM_SP_sim.times_rec
times_clc = WISTEM_SP_sim.times_rec
ntimes = len(times_clc)
print(ntimes)
print(times_clc[:3], times_clc[-3:])
WISTEM_SP_sim.get_window_log(tstart=tstrt,logstep=logstep)
windows_strt = WISTEM_SP_sim.windows_strt
windows_cen = WISTEM_SP_sim.windows_cen
windows_end = WISTEM_SP_sim.windows_end
print(windows_cen-rmp_time)
# Out:
# 500
# [2.e-05 4.e-05 6.e-05] [0.00996 0.00998 0.01   ]
# [0.0001     0.00011659 0.00013594 0.00015849 0.00018478 0.00021544
#  0.00025119 0.00029286 0.00034145 0.00039811 0.00046416 0.00054117
#  0.00063096 0.00073564 0.0008577  0.001      0.00116591 0.00135936
#  0.00158489 0.00184785 0.00215443 0.00251189 0.00292864 0.00341455
#  0.00398107 0.00464159 0.0054117  0.00630957 0.00735642 0.00857696]

# %%
nlayer =1

rho0_target = 0.3
eta_target = 0.4
eta_sea , eta_base = 0.,0.
c_target = 0.5 
thick_target = 10.
tau_target = 100e-3

res_sea = 0.3
res_base = 1.0
tau_sea, tau_base, tau_ref = 1.0e-3, 1.0e-3, 1.0e-3
c_sea, c_base,  = c_target, c_target
tx_height = 0.1 #csx
depth = np.r_[0, thick_target]
depth+=tx_height
print(f"depth {depth}")

print(tx_height)
# Out:
# depth [ 0.1 10.1]
# 0.1

# %%
WISTEM_SP_sim.get_window_log(tstart=tstrt,logstep=logstep)
filt_linrmp = WISTEM_SP_sim.filter_linear_rmp()

Window_mat = WISTEM_SP_sim.get_window_matrix(times_sim)
print(Window_mat.shape)
# Out:
# (30, 500)

# %%
recx, recy = 0 , 0
recBdple = [recx, recy, tx_depth ,0,90]
# recx, recy, recw = rec_area(3, tx_side)
# recBdple = [recx, recy, tx_depth ,0,90]

# %%
# emoymod model to simulate WISTEM setting
# Note that it simulate only dBdt field at center of the transmitter loop
# User should multiply by area of the loop to get EMF(V/A)
empymod_model_sim = {
    # simulate each bipole of four side of the transmitter loop
    'src': [ tx_side/2, tx_side/2,  # x1,x2
                     0, tx_side/2,  # y1,y2
             tx_depth, tx_depth], # z1,z2
    # receiver at the center of the transmitter loop
    'rec': recBdple, # [recx, recy, tx_depth ,0,90], # dBzdt at x,y,z,azimuth,dip
    'depth': depth,
#    'res' : res,
    'freqtime': times_sim,
    'signal': None, # 0, # 0: impulse or dBdt, 1: Stepoff or B field
    'msrc' : False, # Electric source
    'mrec' : True, # Magnetic receiver
    'strength': 8.*n_turns* tx_surface * mu_0,  
    'srcpts' : 3,  # Three works for the momtent, maybe worth seeking other number
    'verb': 0, # put 4 for more information
     # Setting xdirect=True can help, as direct field is then computed analytically in f-domain
    'xdirect': True,
}

# %%
sim_obs=empymod_IP_simulation(ip_model='pelton',
    model_base=empymod_model_sim, nlayer=nlayer,tx_height=tx_height,
    times=times_sim, smp_freq=smp_freq
    )
sim_obs.deepsea_signle_layer(
    res_sea=res_sea, res_base=res_base,
    eta_sea=eta_sea, eta_base=eta_base,
    tau_sea=tau_sea, tau_base=tau_base, 
    c_sea=c_sea, c_base=c_base
    )

# %%
print(sim_obs.m_fix)
print(sim_obs.model_base)
# Out:
# [-1.2039728   0.          0.          0.          0.          0.
#  -6.90775528  0.         -6.90775528  0.5         0.          0.5       ]
# {'src': [1.75, 1.75, 0, 1.75, 0, 0], 'rec': [0, 0, 0, 0, 90], 'depth': array([ 0.1, 10.1]), 'freqtime': array([2.00e-05, 4.00e-05, 6.00e-05, 8.00e-05, 1.00e-04, 1.20e-04,
#        1.40e-04, 1.60e-04, 1.80e-04, 2.00e-04, 2.20e-04, 2.40e-04,
#        2.60e-04, 2.80e-04, 3.00e-04, 3.20e-04, 3.40e-04, 3.60e-04,
#        3.80e-04, 4.00e-04, 4.20e-04, 4.40e-04, 4.60e-04, 4.80e-04,
#        5.00e-04, 5.20e-04, 5.40e-04, 5.60e-04, 5.80e-04, 6.00e-04,
#        6.20e-04, 6.40e-04, 6.60e-04, 6.80e-04, 7.00e-04, 7.20e-04,
#        7.40e-04, 7.60e-04, 7.80e-04, 8.00e-04, 8.20e-04, 8.40e-04,
#        8.60e-04, 8.80e-04, 9.00e-04, 9.20e-04, 9.40e-04, 9.60e-04,
#        9.80e-04, 1.00e-03, 1.02e-03, 1.04e-03, 1.06e-03, 1.08e-03,
#        1.10e-03, 1.12e-03, 1.14e-03, 1.16e-03, 1.18e-03, 1.20e-03,
#        1.22e-03, 1.24e-03, 1.26e-03, 1.28e-03, 1.30e-03, 1.32e-03,
#        1.34e-03, 1.36e-03, 1.38e-03, 1.40e-03, 1.42e-03, 1.44e-03,
#        1.46e-03, 1.48e-03, 1.50e-03, 1.52e-03, 1.54e-03, 1.56e-03,
#        1.58e-03, 1.60e-03, 1.62e-03, 1.64e-03, 1.66e-03, 1.68e-03,
#        1.70e-03, 1.72e-03, 1.74e-03, 1.76e-03, 1.78e-03, 1.80e-03,
#        1.82e-03, 1.84e-03, 1.86e-03, 1.88e-03, 1.90e-03, 1.92e-03,
#        1.94e-03, 1.96e-03, 1.98e-03, 2.00e-03, 2.02e-03, 2.04e-03,
#        2.06e-03, 2.08e-03, 2.10e-03, 2.12e-03, 2.14e-03, 2.16e-03,
#        2.18e-03, 2.20e-03, 2.22e-03, 2.24e-03, 2.26e-03, 2.28e-03,
#        2.30e-03, 2.32e-03, 2.34e-03, 2.36e-03, 2.38e-03, 2.40e-03,
#        2.42e-03, 2.44e-03, 2.46e-03, 2.48e-03, 2.50e-03, 2.52e-03,
#        2.54e-03, 2.56e-03, 2.58e-03, 2.60e-03, 2.62e-03, 2.64e-03,
#        2.66e-03, 2.68e-03, 2.70e-03, 2.72e-03, 2.74e-03, 2.76e-03,
#        2.78e-03, 2.80e-03, 2.82e-03, 2.84e-03, 2.86e-03, 2.88e-03,
#        2.90e-03, 2.92e-03, 2.94e-03, 2.96e-03, 2.98e-03, 3.00e-03,
#        3.02e-03, 3.04e-03, 3.06e-03, 3.08e-03, 3.10e-03, 3.12e-03,
#        3.14e-03, 3.16e-03, 3.18e-03, 3.20e-03, 3.22e-03, 3.24e-03,
#        3.26e-03, 3.28e-03, 3.30e-03, 3.32e-03, 3.34e-03, 3.36e-03,
#        3.38e-03, 3.40e-03, 3.42e-03, 3.44e-03, 3.46e-03, 3.48e-03,
#        3.50e-03, 3.52e-03, 3.54e-03, 3.56e-03, 3.58e-03, 3.60e-03,
#        3.62e-03, 3.64e-03, 3.66e-03, 3.68e-03, 3.70e-03, 3.72e-03,
#        3.74e-03, 3.76e-03, 3.78e-03, 3.80e-03, 3.82e-03, 3.84e-03,
#        3.86e-03, 3.88e-03, 3.90e-03, 3.92e-03, 3.94e-03, 3.96e-03,
#        3.98e-03, 4.00e-03, 4.02e-03, 4.04e-03, 4.06e-03, 4.08e-03,
#        4.10e-03, 4.12e-03, 4.14e-03, 4.16e-03, 4.18e-03, 4.20e-03,
#        4.22e-03, 4.24e-03, 4.26e-03, 4.28e-03, 4.30e-03, 4.32e-03,
#        4.34e-03, 4.36e-03, 4.38e-03, 4.40e-03, 4.42e-03, 4.44e-03,
#        4.46e-03, 4.48e-03, 4.50e-03, 4.52e-03, 4.54e-03, 4.56e-03,
#        4.58e-03, 4.60e-03, 4.62e-03, 4.64e-03, 4.66e-03, 4.68e-03,
#        4.70e-03, 4.72e-03, 4.74e-03, 4.76e-03, 4.78e-03, 4.80e-03,
#        4.82e-03, 4.84e-03, 4.86e-03, 4.88e-03, 4.90e-03, 4.92e-03,
#        4.94e-03, 4.96e-03, 4.98e-03, 5.00e-03, 5.02e-03, 5.04e-03,
#        5.06e-03, 5.08e-03, 5.10e-03, 5.12e-03, 5.14e-03, 5.16e-03,
#        5.18e-03, 5.20e-03, 5.22e-03, 5.24e-03, 5.26e-03, 5.28e-03,
#        5.30e-03, 5.32e-03, 5.34e-03, 5.36e-03, 5.38e-03, 5.40e-03,
#        5.42e-03, 5.44e-03, 5.46e-03, 5.48e-03, 5.50e-03, 5.52e-03,
#        5.54e-03, 5.56e-03, 5.58e-03, 5.60e-03, 5.62e-03, 5.64e-03,
#        5.66e-03, 5.68e-03, 5.70e-03, 5.72e-03, 5.74e-03, 5.76e-03,
#        5.78e-03, 5.80e-03, 5.82e-03, 5.84e-03, 5.86e-03, 5.88e-03,
#        5.90e-03, 5.92e-03, 5.94e-03, 5.96e-03, 5.98e-03, 6.00e-03,
#        6.02e-03, 6.04e-03, 6.06e-03, 6.08e-03, 6.10e-03, 6.12e-03,
#        6.14e-03, 6.16e-03, 6.18e-03, 6.20e-03, 6.22e-03, 6.24e-03,
#        6.26e-03, 6.28e-03, 6.30e-03, 6.32e-03, 6.34e-03, 6.36e-03,
#        6.38e-03, 6.40e-03, 6.42e-03, 6.44e-03, 6.46e-03, 6.48e-03,
#        6.50e-03, 6.52e-03, 6.54e-03, 6.56e-03, 6.58e-03, 6.60e-03,
#        6.62e-03, 6.64e-03, 6.66e-03, 6.68e-03, 6.70e-03, 6.72e-03,
#        6.74e-03, 6.76e-03, 6.78e-03, 6.80e-03, 6.82e-03, 6.84e-03,
#        6.86e-03, 6.88e-03, 6.90e-03, 6.92e-03, 6.94e-03, 6.96e-03,
#        6.98e-03, 7.00e-03, 7.02e-03, 7.04e-03, 7.06e-03, 7.08e-03,
#        7.10e-03, 7.12e-03, 7.14e-03, 7.16e-03, 7.18e-03, 7.20e-03,
#        7.22e-03, 7.24e-03, 7.26e-03, 7.28e-03, 7.30e-03, 7.32e-03,
#        7.34e-03, 7.36e-03, 7.38e-03, 7.40e-03, 7.42e-03, 7.44e-03,
#        7.46e-03, 7.48e-03, 7.50e-03, 7.52e-03, 7.54e-03, 7.56e-03,
#        7.58e-03, 7.60e-03, 7.62e-03, 7.64e-03, 7.66e-03, 7.68e-03,
#        7.70e-03, 7.72e-03, 7.74e-03, 7.76e-03, 7.78e-03, 7.80e-03,
#        7.82e-03, 7.84e-03, 7.86e-03, 7.88e-03, 7.90e-03, 7.92e-03,
#        7.94e-03, 7.96e-03, 7.98e-03, 8.00e-03, 8.02e-03, 8.04e-03,
#        8.06e-03, 8.08e-03, 8.10e-03, 8.12e-03, 8.14e-03, 8.16e-03,
#        8.18e-03, 8.20e-03, 8.22e-03, 8.24e-03, 8.26e-03, 8.28e-03,
#        8.30e-03, 8.32e-03, 8.34e-03, 8.36e-03, 8.38e-03, 8.40e-03,
#        8.42e-03, 8.44e-03, 8.46e-03, 8.48e-03, 8.50e-03, 8.52e-03,
#        8.54e-03, 8.56e-03, 8.58e-03, 8.60e-03, 8.62e-03, 8.64e-03,
#        8.66e-03, 8.68e-03, 8.70e-03, 8.72e-03, 8.74e-03, 8.76e-03,
#        8.78e-03, 8.80e-03, 8.82e-03, 8.84e-03, 8.86e-03, 8.88e-03,
#        8.90e-03, 8.92e-03, 8.94e-03, 8.96e-03, 8.98e-03, 9.00e-03,
#        9.02e-03, 9.04e-03, 9.06e-03, 9.08e-03, 9.10e-03, 9.12e-03,
#        9.14e-03, 9.16e-03, 9.18e-03, 9.20e-03, 9.22e-03, 9.24e-03,
#        9.26e-03, 9.28e-03, 9.30e-03, 9.32e-03, 9.34e-03, 9.36e-03,
#        9.38e-03, 9.40e-03, 9.42e-03, 9.44e-03, 9.46e-03, 9.48e-03,
#        9.50e-03, 9.52e-03, 9.54e-03, 9.56e-03, 9.58e-03, 9.60e-03,
#        9.62e-03, 9.64e-03, 9.66e-03, 9.68e-03, 9.70e-03, 9.72e-03,
#        9.74e-03, 9.76e-03, 9.78e-03, 9.80e-03, 9.82e-03, 9.84e-03,
#        9.86e-03, 9.88e-03, 9.90e-03, 9.92e-03, 9.94e-03, 9.96e-03,
#        9.98e-03, 1.00e-02]), 'signal': None, 'msrc': False, 'mrec': True, 'strength': np.float64(0.0006157521600223001), 'srcpts': 3, 'verb': 0, 'xdirect': True}

# %%
mvec_obs =  np.r_[np.log(rho0_target), eta_target, np.log(tau_target), c_target]
print(mvec_obs)
print(sim_obs.get_ip_model(mvec_obs))
# Out:
# [-1.2039728   0.4        -2.30258509  0.5       ]
# {'res': array([0.3, 0.3, 1. ]), 'rho_0': array([0.3, 0.3, 1. ]), 'm': array([0. , 0.4, 0. ]), 'tau': array([0.001, 0.1  , 0.001]), 'c': array([0.5, 0.5, 0.5]), 'func_eta': <bound method empymod_IP_simulation.pelton_et_al of <masa_utils.empymod_IP_simulation object at 0x00000170FBA22290>>}

# %%
sim_obs.cut_off = None
sim_obs.filt_curr = None
sim_obs.window_mat= None
dpred_step= sim_obs.dpred(mvec_obs)
sim_obs.cut_off = smp_freq/2.0
print(f"cutoff frequency: {sim_obs.cut_off}")
dpred_LPF = sim_obs.dpred(mvec_obs)
sim_obs.filt_curr = filt_linrmp
dpred_rmp = sim_obs.dpred(mvec_obs)
sim_obs.window_mat=Window_mat
dpred_window = sim_obs.dpred(mvec_obs)
# Out:
# cutoff frequency: 25000.0

# %%
PL_decay = PsuedoLog(
    logmin=1e-8,
    linScale=0.7,
    logminx=1e-4,
    linScalex=0.2
    )

PL_jac = PsuedoLog(
    logmin=1e-1,
    linScale=0.5,
    logminx=1e-4,
    linScalex=0.2
    )

# %%
fig, ax= plt.subplots(1,1, figsize=(textwidth ,3.0))

ax=PL_decay.plpl_plot(
     x=times_clc,y=dpred_step , linestyle="-",label="obs", color="C0",ax=ax)
ax=PL_decay.plpl_plot(
     x=times_clc,y=dpred_LPF , linestyle="-",label="Low Pass filtered", color="C1",ax=ax)
ax=PL_decay.plpl_plot(
     x=times_clc-rmp_time,y=dpred_rmp , linestyle="-",label="wvf", color="C2",ax=ax)
ax=PL_decay.plpl_plot(
     x= windows_cen-rmp_time,y=dpred_window , marker="o",linestyle="",label="windowed", color="C3",ax=ax)
ax= PL_decay.pl_axes(ax)
ax = PL_decay.pl_axes_x(ax)


ax.legend()

# %%
relative_error=0.05
data_noise_floor = 1e-8
dobs_clean =  sim_obs.dpred(mvec_obs)

# Calculate noise at each point according to the formula
np.random.seed(1)  # For reproducibility
noise_floor = data_noise_floor
noise_relative = relative_error * np.abs(dobs_clean)

# Combine the two sources of noise quadratically (in terms of variance)
total_noise = np.sqrt(noise_floor**2 + noise_relative**2)

# Add the combined noise to the clean data
dobs = dobs_clean +np.random.randn(len(dobs_clean)) *  total_noise
# data_init = sim_obs.predicted_data(mvec_ref)

# %%
fig, ax= plt.subplots(1,1, figsize=(textwidth ,3.0))
# ax=PL_decay.plpl_plot(x= windows_cen-rmp_time,y=data_init,
#    label="ref/init", color="C0", marker="o",markersize=4,ax=ax
# )
ax=PL_decay.plpl_plot(x= windows_cen-rmp_time,y=dobs, 
   label="dobs", color="C1", marker="o",markersize=4,ax=ax
)
ax= PL_decay.pl_axes(ax)
ax = PL_decay.pl_axes_x(ax)

ax.legend()

# %% [markdown]
# # Invert with Debye Decomposition model

# %%
nrange=3
taus_strt_log = -3.50*np.ones(nrange) # np.r_[-3.25, -3.25, -3.25]
# taus_strt_log = np.r_[-4.0, -4.0, -4.0]
taus_end_log  = np.r_[-2.75, -2.25, -1.25]
#taus_end_log  = np.r_[-2.00, -1.75, -1.50]
taus_end = 10**taus_end_log
taus_strt = 10**taus_strt_log
print(taus_end)
print(taus_strt)
taus_step_log = 0.25

taus_max, taus_min = taus_end_log.max(), taus_strt_log.min()
# Out:
# [0.00177828 0.00562341 0.05623413]
# [0.00031623 0.00031623 0.00031623]

# %%
taus_cmb = []
m_refs = []
taus_colors = []
sim_inv = []
Wd_refs = []
J_refs = []
ntau_cmb= []
for i in range(nrange):
    ntau =  int((taus_end_log[i] - taus_strt_log[i])/taus_step_log) +1
    taus= np.logspace(taus_strt_log[i], taus_end_log[i], ntau, endpoint=True)

    taus_color = (np.linspace(taus_strt_log[i], taus_end_log[i], ntau)-taus_min)/ (taus_max-taus_min)
    m_ref = np.r_[np.log(res_sea), np.zeros(ntau)]
    print(taus) 
    print(taus_color)
    taus_cmb.append(taus)
    ntau_cmb.append(ntau)
    taus_colors.append(taus_color)
    m_refs.append(m_ref)
    sim=empymod_IP_simulation(ip_model='DDR',chgmin=0,
        model_base=empymod_model_sim, nlayer=nlayer,tx_height=tx_height,
        taus=taus, times=times_sim, smp_freq=smp_freq
    )
    sim.deepsea_signle_layer(
        res_sea=res_sea, res_base=res_base, eta_sea=eta_sea, eta_base=eta_base  
        )
    dpred_step= sim.dpred(m_ref)
    sim.cut_off = smp_freq/2.0
    dpred_LPF = sim.dpred(m_ref)
    sim.filt_curr = filt_linrmp
    dpred_rmp = sim.dpred(m_ref)
    sim.window_mat=Window_mat
    dpred_window = sim.dpred(m_ref)
    sim_inv.append(sim) 
    opt = Optimization(sim=sim_inv[i], dobs=dpred_window)
    opt.get_Wd(ratio=relative_error, plateau=data_noise_floor )
    Wd_refs.append(opt.Wd)
    J_refs.append(sim_inv[i].J(m_ref))
Wd_ref = Wd_refs[0]
ntau_max = max(ntau_cmb)
# Out:
# [0.00031623 0.00056234 0.001      0.00177828]
# [0.         0.11111111 0.22222222 0.33333333]
# [0.00031623 0.00056234 0.001      0.00177828 0.00316228 0.00562341]
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556]
# [0.00031623 0.00056234 0.001      0.00177828 0.00316228 0.00562341
#  0.01       0.01778279 0.03162278 0.05623413]
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ]

# %%
taus_colors
# Out:
# [array([0.        , 0.11111111, 0.22222222, 0.33333333]),
#  array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#         0.55555556]),
#  array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#         0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])]

# %%
U_ddr_refs = []
U_ddr_recs = []
S_ddr_refs = []
S_ddr_recs = []
V_ddr_refs = []
V_ddr_recs = []
Jprd_refs = []
Jprd_recs = []
J_refs = []
J_recs = []
for i in range(nrange):
    sim = sim_inv[i]
    Wd_ref = Wd_refs[i]
    m_ref = m_refs[i]
    jacobian = sim.J(m_ref)
    J_refs.append(jacobian)
    U, S, V = np.linalg.svd(Wd_ref@jacobian, full_matrices=False)
    U_ddr_refs.append(U)
    V_ddr_refs.append(V)
    s_norm = S/S.max()
    S_ddr_refs.append(s_norm)
    Jprd = sim.J_prd(Wd_ref@jacobian)
    Jprd_refs.append(abs(Jprd))

sim = sim_obs
jacobian = sim_obs.J(mvec_obs)
J_refs.append(jacobian)
U, S, V = np.linalg.svd(Wd_ref@jacobian, full_matrices=False)
U_ddr_refs.append(U)
V_ddr_refs.append(V)
s_norm = S/S.max()
S_pelton = s_norm
Jprd = sim_obs.J_prd(Wd_ref@jacobian)
Jprd_pelton = abs(Jprd)

# %%
fig, ax= plt.subplots(1,1, figsize=(textwidth ,3.0))

ax=PL_decay.plpl_plot(
     x=times_clc,y=dpred_step , linestyle="-",label="obs", color="C0",ax=ax)
ax=PL_decay.plpl_plot(
     x=times_clc,y=dpred_LPF , linestyle="-",label="Low Pass filtered", color="C1",ax=ax)
ax=PL_decay.plpl_plot(
     x=times_clc-rmp_time,y=dpred_rmp , linestyle="-",label="wvf", color="C2",ax=ax)
ax=PL_decay.plpl_plot(
     x= windows_cen-rmp_time,y=dpred_window , marker="o",linestyle="",label="windowed", color="C3",ax=ax)
ax= PL_decay.pl_axes(ax)
ax = PL_decay.pl_axes_x(ax)
#for ax in ax:
ax.legend()

# %%
colormap = plt.get_cmap("cool")

# %%
def plot_data(data_init, dpred, ax=None):
    if ax is None: 
        fig, ax = plt.subplots(1, 1, figsize=(5,3))
       
    ax=PL_decay.semiply(windows_cen-rmp_time, data_init, ax=ax,
                       color="C1",label="ref" #
                       )
    ax=PL_decay.semiply(windows_cen-rmp_time, dpred, ax=ax
                        ,color="C0",linestyle="-",
                        label=f"est"# mated, iter={iteration}"
                        )
    ax=PL_decay.semiply(windows_cen-rmp_time, dobs, ax=ax, marker=".",markersize=2.0,
                       color="C3",linestyle="", label="obs"
                       )
    ax = PL_decay.pl_axes(ax)
    # ax.grid()
    # ax.legend()
    ax.set_xlabel("Time (s)")
    ax.set_ylabel("EMF (V/A)")

#     ax.set_title(f""" Data plot
# Relative error {relative_error*100:.1f} %, noise floor {data_noise_floor:.1e}""")
    return ax

# %%
def plot_jacobian(irange, indbold=None,ax=None, unit=None):
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(5,3))
    taus = taus_cmb[irange]
    taus_color = taus_colors[irange]
    ntau = ntau_cmb[irange]
    J_ref = J_refs[irange]
    Wd_ref = Wd_refs[irange]
    rho0 = Wd_ref@J_ref[:,0]
    windows_maxrho0 = windows_cen[np.argmax(np.abs(rho0))]
    for j in range(ntau):
        color = colormap(taus_color[j])
        linewidth = 1
        linestyle ='-'
        if j == indbold:
            linewidth = 2.0
            linestyle ='--'
        # label = rf"$\Delta\eta_{{{j+1}}}, \tau_{{{j+1}}}: \SI{{{taus[j]:.1e}}}{{\second}}$"
        label = rf"$\Delta\eta_{{{j+1}}}, \tau_{{{j+1}}}: {sci_latex(taus[j], prec=1)} s$"
        y = Wd_ref @ J_ref[:, j + nlayer]
        if unit:
            y/= np.linalg.norm(y)
        ax = PL_jac.semiply(
            x=windows_cen - rmp_time,
            y=y,
            color=color,
            linestyle=linestyle,
            label=label,
            linewidth=linewidth,
            ax=ax
        )

    ax=PL_jac.semiply(
        windows_cen-rmp_time, Wd_ref@J_ref[:,0],color="k",label=r"+$\Delta\log{\rho_0}$",ax=ax,
            linestyle="--", linewidth=1#, marker="o",markersize=4
            )

    ax=PL_jac.semiply(
        windows_cen-rmp_time, -Wd_ref@J_ref[:,0],color="k",label=r"-$\Delta\log{\rho_0}$",ax=ax,
            linestyle="-.", linewidth=1#, marker="o",markersize=4
            )
    ax.axvline(x=windows_maxrho0-rmp_time,  color="k", linestyle=":", label=r"peak of $-\Delta\log{\rho_0}$")
    ax= PL_jac.pl_axes(ax)
    ax.set_xlabel("Time (s)")
    ax.set_title(fr"$W_dJ$ for $\tau_k$ band_{irange+1}")
    return ax

# %%
def plot_taus(irange,ax=None):
    if ax is None:
        fig , ax = plt.subplots(1,1, figsize=(5,3))

    taus = taus_cmb[irange]
    taus_color = taus_colors[irange]
    ntau = ntau_cmb[irange]
    for j in range(ntau):
        color = colormap(taus_color[j])
        ax.semilogx(taus[j], irange, 
            linestyle="", marker="o", color=color, markersize=2.0)
    ax.set_yticks(np.arange(0, nrange))
    ax.set_yticklabels([fr"$\tau_k$ band_{i+1}" for i in range(nrange)])
    ax.invert_yaxis()
    ax.set_title(r"$\tau_k$ for each model")
    ax.set_xlabel(r"$\tau_k$ (s)")
    return ax

# %%
def plot_cnd(S,ax=None, label=None):
    if ax is None:
        fig , ax = plt.subplots(1,1, figsize=(5,3))
    ax.semilogy(S, linestyle="-", marker="o",
                   label=label) # max($\tau_j$): {tau_end:.2e}")
    ax.set_xticks(np.arange(ntau_max+1))
    ax.set_xticklabels(np.arange(1,ntau_max+2))
    ax.set_xlabel("Singular Value Index")
    ax.set_title("Condition Number")

    return ax

# %%
fig, ax = plt.subplots(2, 2, figsize=(textwidth ,3))
ax_jacobian = ax[0, 0]
ax_cnd = ax[1, 1]
ax_tau = ax[1, 0]
ax_color =ax[0, 1]

taus = taus_cmb[2]
ntau = ntau_cmb[2]

ax_jacobian =  plot_jacobian(irange=2, indbold=7, ax=ax_jacobian)
for i in range(nrange-1,-1,-1):
    ax_cnd=plot_cnd(S_ddr_refs[i], ax=ax_cnd, label= f"model_{i}")
    ax_tau=plot_taus(irange=i, ax=ax_tau)
ax_cnd = plot_cnd(S_pelton, ax=ax_cnd, label="Pelton")

ax_cnd.legend()
ax_color.axis("off")
handles, labels = ax_jacobian.get_legend_handles_labels()
ax_color.legend(handles, labels, title="Jacobian Component",
                loc="upper right",ncol=2)

axis_to_label = [ax_jacobian,ax_tau,ax_cnd]
panel_labels = ['(a)', '(b)', '(c)']
ax = ax.flatten()

for label, axis in zip(panel_labels, axis_to_label):
    axis.text(
        -0.15, 1.05, label,
        transform=axis.transAxes,
         fontweight='bold',
        va='bottom', ha='right'
    )

# %%
colormap = plt.get_cmap("turbo")

# %%
fig = plt.figure(figsize=(textwidth , 4.0))


gs = fig.add_gridspec(
    2, 2,
    height_ratios=[1, 0.8],
    width_ratios=[1, 1]
)

ax_jacobian = fig.add_subplot(gs[:, 0])
ax_tau      = fig.add_subplot(gs[0, 1])
ax_color    = fig.add_subplot(gs[1, 1])

taus = taus_cmb[2]
ntau = ntau_cmb[2]

indbold = 5
irange= 2
ax_jacobian =  plot_jacobian(irange=irange, indbold=indbold, ax=ax_jacobian)
color = colormap(taus_colors[irange][indbold])
for i in range(nrange-1,-1,-1):
    ax_tau=plot_taus(irange=i, ax=ax_tau)
x= taus[indbold]
ax_tau.axvline(x=x, color=color, linestyle='-.', 
        alpha=0.5,label = r"$\Delta\eta_k$ with minimum at latest time channel")
ax_tau.axvline(x=tau_target, color='C3', linestyle='-.', 
        alpha=0.5,label = r"Target time constant$\tau_\rho$")

ax_tau.legend(loc='upper center', bbox_to_anchor=(0.5, -0.20), ncol=1)

ax_color.axis("off")
handles, labels = ax_jacobian.get_legend_handles_labels()
ax_color.legend(handles, labels, 
                title="Jacobian Component",loc="upper right",ncol=2)
fig.canvas.draw()

labels_axes = [
    ('(a)', ax_jacobian),
    ('(b)', ax_tau),
    # ('(c)', ax_color),
]

for lab, ax in labels_axes:
    pos = ax.get_position()
    fig.text(
        pos.x0 - 0.02,     # left of THIS axis
        pos.y1 + 0.01,     # above THIS axis
        lab,
         fontweight='bold',
        ha='right', va='bottom'
    )
plt.savefig('../figures/43_DD_TEM_Jacobian.png')
plt.savefig('../manuscript/figures/43_DD_TEM_Jacobian.pdf')

# %% [markdown]
# # Inversion: Single layer fixed thickness

# %%
niter = 50
stol=1e-6
coolingFactor = 2 #np.sqrt(2) #2.0
coolingRate = 2
mu=1e-3
beta0_ratio = 1.0
alphas= 1.0
Ws_threshold= 0.1 # 1e-3

# %%
models_rec = []
dpreds = []
error_prgs = []
model_prgs = []
dinit_refs = []
data_prgs =[]
betas_prgs = []
for i in range(nrange):
    m_ref = m_refs[i]
    sim = sim_inv[i]
    opt = Optimization(sim=sim, dobs=dobs, alphas=alphas, Ws_threshold=Ws_threshold)
    opt.get_Wd(ratio=relative_error, plateau=data_noise_floor )
    opt.get_Ws(smallness=np.ones(len(m_ref)))
    beta0 = opt.BetaEstimate_byEig(
        mvec=m_ref, update_Wsen=True, beta0_ratio=beta0_ratio)
    print(beta0)
    mpred = opt.GaussNewton(
    mvec_init=m_ref,niter=niter,beta0=beta0, update_Wsen=True,
    stol=stol,mu=mu,coolingRate=coolingRate, coolingFactor=coolingFactor
    )
    
    dinit_refs.append(opt.dpred(m_ref))
    models_rec.append(mpred)
    dpreds.append(opt.dpred(mpred))
    error_prgs.append(opt.error_prg)
    model_prgs.append(opt.mvec_prg)
    data_prgs.append(opt.data_prg)
    betas_prgs.append(opt.betas)
# Out:
# 151481598.19030923
#   1, beta:1.5e+08, step:1.0e+00, g:5.6e+04, phid:3.2e+03, phim:7.9e-08, f:3.2e+03
#   2, beta:1.5e+08, step:9.5e-07, g:4.1e+01, phid:3.2e+03, phim:7.9e-08, f:3.2e+03
#   3, beta:7.6e+07, step:1.0e+00, g:2.8e+04, phid:3.1e+03, phim:3.1e-07, f:3.2e+03
#   4, beta:7.6e+07, step:9.5e-07, g:3.8e+01, phid:3.1e+03, phim:3.1e-07, f:3.2e+03
#   5, beta:3.8e+07, step:1.0e+00, g:2.7e+04, phid:3.1e+03, phim:1.2e-06, f:3.1e+03
#   6, beta:3.8e+07, step:9.5e-07, g:6.9e+01, phid:3.1e+03, phim:1.2e-06, f:3.1e+03
#   7, beta:1.9e+07, step:1.0e+00, g:2.7e+04, phid:2.9e+03, phim:4.2e-06, f:3.0e+03
#   8, beta:1.9e+07, step:9.5e-07, g:1.8e+02, phid:2.9e+03, phim:4.2e-06, f:3.0e+03
#   9, beta:9.5e+06, step:1.0e+00, g:2.6e+04, phid:2.7e+03, phim:1.4e-05, f:2.8e+03
#  10, beta:9.5e+06, step:9.5e-07, g:7.9e+02, phid:2.7e+03, phim:1.4e-05, f:2.8e+03
#  11, beta:4.7e+06, step:1.0e+00, g:2.4e+04, phid:2.3e+03, phim:4.3e-05, f:2.5e+03
#  12, beta:4.7e+06, step:1.0e+00, g:1.7e+03, phid:2.3e+03, phim:4.3e-05, f:2.5e+03
#  13, beta:2.4e+06, step:1.0e+00, g:2.1e+04, phid:1.8e+03, phim:1.1e-04, f:2.1e+03
#  14, beta:2.4e+06, step:1.0e+00, g:3.1e+03, phid:1.8e+03, phim:1.2e-04, f:2.1e+03
#  15, beta:1.2e+06, step:1.0e+00, g:1.7e+04, phid:1.4e+03, phim:2.6e-04, f:1.7e+03
#  16, beta:1.2e+06, step:1.0e+00, g:5.1e+03, phid:1.3e+03, phim:2.7e-04, f:1.6e+03
#  17, beta:5.9e+05, step:1.0e+00, g:1.2e+04, phid:9.5e+02, phim:4.9e-04, f:1.2e+03
#  18, beta:5.9e+05, step:1.0e+00, g:7.6e+03, phid:9.0e+02, phim:5.2e-04, f:1.2e+03
#  19, beta:3.0e+05, step:1.0e+00, g:7.9e+03, phid:6.4e+02, phim:8.0e-04, f:8.7e+02
#  20, beta:3.0e+05, step:1.0e+00, g:8.6e+03, phid:6.0e+02, phim:8.4e-04, f:8.5e+02
#  21, beta:1.5e+05, step:1.0e+00, g:6.9e+03, phid:4.0e+02, phim:1.2e-03, f:5.7e+02
#  22, beta:1.5e+05, step:1.0e+00, g:7.0e+03, phid:3.8e+02, phim:1.2e-03, f:5.5e+02
#  23, beta:7.4e+04, step:1.0e+00, g:5.5e+03, phid:2.6e+02, phim:1.6e-03, f:3.8e+02
#  24, beta:7.4e+04, step:1.0e+00, g:6.6e+03, phid:2.5e+02, phim:1.7e-03, f:3.8e+02
#  25, beta:3.7e+04, step:1.0e+00, g:5.8e+03, phid:2.0e+02, phim:2.2e-03, f:2.8e+02
#  26, beta:3.7e+04, step:1.0e+00, g:7.3e+03, phid:2.0e+02, phim:2.2e-03, f:2.8e+02
#  27, beta:1.8e+04, step:5.0e-01, g:6.4e+03, phid:2.2e+02, phim:2.5e-03, f:2.7e+02
#  28, beta:1.8e+04, step:9.5e-07, g:1.5e+04, phid:2.2e+02, phim:2.5e-03, f:2.7e+02
#  29, beta:9.2e+03, step:3.1e-02, g:1.5e+04, phid:2.4e+02, phim:2.5e-03, f:2.6e+02
#  30, beta:9.2e+03, step:9.5e-07, g:1.7e+04, phid:2.4e+02, phim:2.5e-03, f:2.6e+02
#  31, beta:4.6e+03, step:7.8e-03, g:1.7e+04, phid:2.4e+02, phim:2.5e-03, f:2.5e+02
#  32, beta:4.6e+03, step:9.5e-07, g:1.8e+04, phid:2.4e+02, phim:2.5e-03, f:2.5e+02
#  33, beta:2.3e+03, step:3.9e-03, g:1.7e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  34, beta:2.3e+03, step:9.5e-07, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  35, beta:1.2e+03, step:9.8e-04, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  36, beta:1.2e+03, step:9.5e-07, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  37, beta:5.8e+02, step:4.9e-04, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  38, beta:5.8e+02, step:9.5e-07, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  39, beta:2.9e+02, step:2.4e-04, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  40, beta:2.9e+02, step:9.5e-07, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  41, beta:1.4e+02, step:1.2e-04, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  42, beta:1.4e+02, step:9.5e-07, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  43, beta:7.2e+01, step:6.1e-05, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  44, beta:7.2e+01, step:9.5e-07, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  45, beta:3.6e+01, step:3.1e-05, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  46, beta:3.6e+01, step:9.5e-07, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  47, beta:1.8e+01, step:1.5e-05, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  48, beta:1.8e+01, step:9.5e-07, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  49, beta:9.0e+00, step:7.6e-06, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
#  50, beta:9.0e+00, step:9.5e-07, g:1.8e+04, phid:2.5e+02, phim:2.5e-03, f:2.5e+02
# 175031296.0086034
#   1, beta:1.8e+08, step:1.0e+00, g:6.4e+04, phid:3.2e+03, phim:1.2e-07, f:3.2e+03
#   2, beta:1.8e+08, step:9.5e-07, g:1.4e+02, phid:3.2e+03, phim:1.2e-07, f:3.2e+03
#   3, beta:8.8e+07, step:1.0e+00, g:3.1e+04, phid:3.1e+03, phim:4.7e-07, f:3.1e+03
#   4, beta:8.8e+07, step:9.5e-07, g:1.3e+02, phid:3.1e+03, phim:4.7e-07, f:3.1e+03
#   5, beta:4.4e+07, step:1.0e+00, g:3.1e+04, phid:2.9e+03, phim:1.8e-06, f:3.0e+03
#   6, beta:4.4e+07, step:9.5e-07, g:2.5e+02, phid:2.9e+03, phim:1.8e-06, f:3.0e+03
#   7, beta:2.2e+07, step:1.0e+00, g:3.0e+04, phid:2.6e+03, phim:6.4e-06, f:2.8e+03
#   8, beta:2.2e+07, step:9.5e-07, g:4.6e+02, phid:2.6e+03, phim:6.5e-06, f:2.8e+03
#   9, beta:1.1e+07, step:1.0e+00, g:2.9e+04, phid:2.2e+03, phim:2.1e-05, f:2.4e+03
#  10, beta:1.1e+07, step:9.5e-07, g:9.8e+02, phid:2.2e+03, phim:2.1e-05, f:2.5e+03
#  11, beta:5.5e+06, step:1.0e+00, g:2.6e+04, phid:1.6e+03, phim:5.9e-05, f:2.0e+03
#  12, beta:5.5e+06, step:9.5e-07, g:1.7e+03, phid:1.6e+03, phim:6.1e-05, f:2.0e+03
#  13, beta:2.7e+06, step:1.0e+00, g:2.2e+04, phid:1.0e+03, phim:1.4e-04, f:1.4e+03
#  14, beta:2.7e+06, step:9.5e-07, g:2.8e+03, phid:1.0e+03, phim:1.4e-04, f:1.4e+03
#  15, beta:1.4e+06, step:1.0e+00, g:1.6e+04, phid:5.9e+02, phim:2.6e-04, f:9.4e+02
#  16, beta:1.4e+06, step:9.5e-07, g:4.3e+03, phid:5.9e+02, phim:2.7e-04, f:9.5e+02
#  17, beta:6.8e+05, step:1.0e+00, g:1.0e+04, phid:3.3e+02, phim:3.9e-04, f:5.9e+02
#  18, beta:6.8e+05, step:9.5e-07, g:5.8e+03, phid:3.3e+02, phim:4.0e-04, f:6.0e+02
#  19, beta:3.4e+05, step:1.0e+00, g:5.8e+03, phid:1.9e+02, phim:5.2e-04, f:3.7e+02
#  20, beta:3.4e+05, step:1.0e+00, g:6.1e+03, phid:1.8e+02, phim:5.3e-04, f:3.7e+02
#  21, beta:1.7e+05, step:1.0e+00, g:4.9e+03, phid:1.1e+02, phim:6.4e-04, f:2.2e+02
#  22, beta:1.7e+05, step:1.0e+00, g:5.0e+03, phid:1.0e+02, phim:6.5e-04, f:2.1e+02
#  23, beta:8.5e+04, step:1.0e+00, g:4.1e+03, phid:5.8e+01, phim:7.7e-04, f:1.2e+02
#  24, beta:8.5e+04, step:1.0e+00, g:3.0e+03, phid:5.6e+01, phim:7.8e-04, f:1.2e+02
#  25, beta:4.3e+04, step:1.0e+00, g:2.5e+03, phid:3.7e+01, phim:8.8e-04, f:7.5e+01
#  26, beta:4.3e+04, step:1.0e+00, g:1.2e+03, phid:3.7e+01, phim:8.9e-04, f:7.4e+01
#  27, beta:2.1e+04, step:1.0e+00, g:1.0e+03, phid:3.1e+01, phim:9.6e-04, f:5.2e+01
#  28, beta:2.1e+04, step:1.0e+00, g:3.4e+01, phid:3.1e+01, phim:9.6e-04, f:5.1e+01
#  29, beta:1.1e+04, step:1.0e+00, g:1.9e+02, phid:3.0e+01, phim:1.0e-03, f:4.0e+01
#  30, beta:1.1e+04, step:1.0e+00, g:7.9e+00, phid:3.0e+01, phim:1.0e-03, f:4.0e+01
#  31, beta:5.3e+03, step:1.0e+00, g:1.0e+02, phid:2.9e+01, phim:1.0e-03, f:3.5e+01
#  32, beta:5.3e+03, step:1.0e+00, g:2.4e+00, phid:2.9e+01, phim:1.0e-03, f:3.5e+01
#  33, beta:2.7e+03, step:1.0e+00, g:5.0e+01, phid:2.9e+01, phim:1.1e-03, f:3.2e+01
#  34, beta:2.7e+03, step:9.5e-07, g:9.4e-01, phid:2.9e+01, phim:1.1e-03, f:3.2e+01
#  35, beta:1.3e+03, step:1.0e+00, g:2.7e+01, phid:2.9e+01, phim:1.1e-03, f:3.0e+01
#  36, beta:1.3e+03, step:1.0e+00, g:6.0e-01, phid:2.9e+01, phim:1.1e-03, f:3.0e+01
#  37, beta:6.7e+02, step:5.0e-01, g:1.4e+01, phid:2.9e+01, phim:1.1e-03, f:3.0e+01
#  38, beta:6.7e+02, step:9.5e-07, g:1.1e+03, phid:2.9e+01, phim:1.1e-03, f:3.0e+01
#  39, beta:3.3e+02, step:1.6e-02, g:1.1e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  40, beta:3.3e+02, step:9.5e-07, g:1.5e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  41, beta:1.7e+02, step:3.9e-03, g:1.5e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  42, beta:1.7e+02, step:9.5e-07, g:1.7e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  43, beta:8.3e+01, step:9.8e-04, g:1.7e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  44, beta:8.3e+01, step:9.5e-07, g:1.8e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  45, beta:4.2e+01, step:2.4e-04, g:1.8e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  46, beta:4.2e+01, step:9.5e-07, g:1.9e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  47, beta:2.1e+01, step:1.2e-04, g:1.9e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  48, beta:2.1e+01, step:9.5e-07, g:1.9e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  49, beta:1.0e+01, step:6.1e-05, g:1.9e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
#  50, beta:1.0e+01, step:9.5e-07, g:1.9e+03, phid:2.9e+01, phim:1.1e-03, f:2.9e+01
# 175616715.33205375
#   1, beta:1.8e+08, step:1.0e+00, g:6.4e+04, phid:3.1e+03, phim:1.5e-07, f:3.2e+03
#   2, beta:1.8e+08, step:1.0e+00, g:8.8e+02, phid:3.1e+03, phim:1.5e-07, f:3.2e+03
#   3, beta:8.8e+07, step:1.0e+00, g:3.2e+04, phid:3.0e+03, phim:5.8e-07, f:3.1e+03
#   4, beta:8.8e+07, step:1.0e+00, g:7.6e+02, phid:3.0e+03, phim:5.9e-07, f:3.1e+03
#   5, beta:4.4e+07, step:1.0e+00, g:3.1e+04, phid:2.8e+03, phim:2.2e-06, f:2.9e+03
#   6, beta:4.4e+07, step:1.0e+00, g:9.7e+02, phid:2.8e+03, phim:2.3e-06, f:2.9e+03
#   7, beta:2.2e+07, step:1.0e+00, g:3.1e+04, phid:2.5e+03, phim:8.1e-06, f:2.7e+03
#   8, beta:2.2e+07, step:1.0e+00, g:1.7e+03, phid:2.5e+03, phim:8.8e-06, f:2.7e+03
#   9, beta:1.1e+07, step:1.0e+00, g:3.0e+04, phid:1.9e+03, phim:2.7e-05, f:2.2e+03
#  10, beta:1.1e+07, step:1.0e+00, g:2.9e+03, phid:1.8e+03, phim:3.2e-05, f:2.1e+03
#  11, beta:5.5e+06, step:1.0e+00, g:3.0e+04, phid:9.6e+02, phim:8.0e-05, f:1.4e+03
#  12, beta:5.5e+06, step:1.0e+00, g:3.3e+03, phid:8.2e+02, phim:9.8e-05, f:1.4e+03
#  13, beta:2.7e+06, step:1.0e+00, g:2.7e+04, phid:2.7e+02, phim:1.6e-04, f:7.1e+02
#  14, beta:2.7e+06, step:9.5e-07, g:1.1e+03, phid:2.7e+02, phim:1.8e-04, f:7.7e+02
#  15, beta:1.4e+06, step:1.0e+00, g:1.5e+04, phid:9.2e+01, phim:2.2e-04, f:3.9e+02
#  16, beta:1.4e+06, step:9.5e-07, g:4.2e+02, phid:9.2e+01, phim:2.3e-04, f:4.1e+02
#  17, beta:6.9e+05, step:1.0e+00, g:8.2e+03, phid:5.0e+01, phim:2.5e-04, f:2.2e+02
#  18, beta:6.9e+05, step:9.5e-07, g:4.3e+02, phid:5.0e+01, phim:2.5e-04, f:2.2e+02
#  19, beta:3.4e+05, step:1.0e+00, g:4.1e+03, phid:3.8e+01, phim:2.7e-04, f:1.3e+02
#  20, beta:3.4e+05, step:9.5e-07, g:2.3e+02, phid:3.8e+01, phim:2.7e-04, f:1.3e+02
#  21, beta:1.7e+05, step:1.0e+00, g:2.1e+03, phid:3.3e+01, phim:2.8e-04, f:8.1e+01
#  22, beta:1.7e+05, step:9.5e-07, g:1.8e+01, phid:3.3e+01, phim:2.8e-04, f:8.1e+01
#  23, beta:8.6e+04, step:1.0e+00, g:1.2e+03, phid:3.1e+01, phim:2.9e-04, f:5.6e+01
#  24, beta:8.6e+04, step:1.0e+00, g:9.9e+00, phid:3.1e+01, phim:2.8e-04, f:5.6e+01
#  25, beta:4.3e+04, step:1.0e+00, g:6.0e+02, phid:3.0e+01, phim:2.9e-04, f:4.3e+01
#  26, beta:4.3e+04, step:1.0e+00, g:3.6e+00, phid:3.0e+01, phim:2.9e-04, f:4.3e+01
#  27, beta:2.1e+04, step:1.0e+00, g:3.1e+02, phid:3.0e+01, phim:3.0e-04, f:3.6e+01
#  28, beta:2.1e+04, step:1.0e+00, g:1.5e+00, phid:3.0e+01, phim:3.0e-04, f:3.6e+01
#  29, beta:1.1e+04, step:1.0e+00, g:1.6e+02, phid:3.0e+01, phim:3.1e-04, f:3.3e+01
#  30, beta:1.1e+04, step:1.0e+00, g:4.2e+00, phid:3.0e+01, phim:3.1e-04, f:3.3e+01
#  31, beta:5.4e+03, step:1.0e+00, g:7.8e+01, phid:2.9e+01, phim:3.2e-04, f:3.1e+01
#  32, beta:5.4e+03, step:1.0e+00, g:6.9e+00, phid:2.9e+01, phim:3.2e-04, f:3.1e+01
#  33, beta:2.7e+03, step:1.0e+00, g:3.9e+01, phid:2.9e+01, phim:3.4e-04, f:3.0e+01
#  34, beta:2.7e+03, step:5.0e-01, g:1.1e+01, phid:2.9e+01, phim:3.4e-04, f:3.0e+01
#  35, beta:1.3e+03, step:1.0e+00, g:1.6e+01, phid:2.9e+01, phim:4.0e-04, f:3.0e+01
#  36, beta:1.3e+03, step:2.5e-01, g:1.9e+01, phid:2.9e+01, phim:3.9e-04, f:3.0e+01
#  37, beta:6.7e+02, step:5.0e-01, g:9.8e+00, phid:2.9e+01, phim:4.6e-04, f:2.9e+01
#  38, beta:6.7e+02, step:6.2e-02, g:1.2e+01, phid:2.9e+01, phim:4.6e-04, f:2.9e+01
#  39, beta:3.3e+02, step:3.1e-02, g:1.0e+01, phid:2.9e+01, phim:4.7e-04, f:2.9e+01
#  40, beta:3.3e+02, step:9.5e-07, g:7.6e+02, phid:2.9e+01, phim:4.7e-04, f:2.9e+01
#  41, beta:1.7e+02, step:3.9e-03, g:7.6e+02, phid:2.9e+01, phim:4.7e-04, f:2.9e+01
#  42, beta:1.7e+02, step:9.5e-07, g:9.4e+02, phid:2.9e+01, phim:4.7e-04, f:2.9e+01
#  43, beta:8.4e+01, step:9.8e-04, g:9.4e+02, phid:2.9e+01, phim:4.8e-04, f:2.9e+01
#  44, beta:8.4e+01, step:9.5e-07, g:1.0e+03, phid:2.9e+01, phim:4.8e-04, f:2.9e+01
#  45, beta:4.2e+01, step:4.9e-04, g:1.0e+03, phid:2.9e+01, phim:4.8e-04, f:2.9e+01
#  46, beta:4.2e+01, step:9.5e-07, g:1.1e+03, phid:2.9e+01, phim:4.8e-04, f:2.9e+01
#  47, beta:2.1e+01, step:2.4e-04, g:1.1e+03, phid:2.9e+01, phim:4.8e-04, f:2.9e+01
#  48, beta:2.1e+01, step:9.5e-07, g:1.1e+03, phid:2.9e+01, phim:4.8e-04, f:2.9e+01
#  49, beta:1.0e+01, step:6.1e-05, g:1.1e+03, phid:2.9e+01, phim:4.8e-04, f:2.9e+01
#  50, beta:1.0e+01, step:9.5e-07, g:1.1e+03, phid:2.9e+01, phim:4.8e-04, f:2.9e+01

# %%
phid_star=len(windows_cen)
models_rec_phid = []
dpreds_phid = []
phid_star_ratio =1.1
phid_itrs = []
chis = []
for i in range(nrange):
    model_prg= np.array(model_prgs[i])
    data_prg = np.array(data_prgs[i])
    error_prg = error_prgs[i]
    phid_prg = np.array(error_prg)[:,1]
    ind = phid_prg < phid_star*phid_star_ratio
    if np.sum(ind) == 0:
        print(f" range {i}:No phid star found, take min phid")
        ind = phid_prg == np.min(phid_prg)
    phid = phid_prg[ind][0]
    phid_itr = np.where(ind)[0][0]
    models_rec_phid.append(model_prg[ind][0])
    dpreds_phid.append(data_prg[ind][0])
    phid_itrs.append(phid_itr)
    chis.append(phid/phid_star)
# Out:
#  range 0:No phid star found, take min phid

# %%
chis
# Out:
# [np.float64(6.573675839947575),
#  np.float64(1.0371448988629899),
#  np.float64(1.0471713565306784)]

# %%
print( "Parameter:  $\\rho_0$, $\\eta$, $\\tau_max$")
np_mvec_refs= []
np_mvec_ests= []
for i in range(nrange):
    np_mvec_ref = m_refs[i]
    # mvec_est = models_rec[i]
    mvec_est = models_rec_phid[i]
    taus_max = taus_cmb[i].max()
    np_mvec_refs.append(np_mvec_ref)
    np_mvec_ests.append(mvec_est)
    # print(f"ref{i+1}     & {np.exp(np_mvec_ref[0]):.2e} & {np_mvec_ref[1:].sum():.3f} ")
    # print(f"est{i+1}     & {np.exp(np_mvec_est[0]):.2e} & { np_mvec_est[1:].sum():.3f} & {taus_max:.2e}")
    print(f"est_phid{i+1}& {np.exp(mvec_est[0]):.2e} & {mvec_est[1:].sum():.3f} & {taus_max:.2e}")
# Out:
# Parameter:  $\rho_0$, $\eta$, $\tau_max$
# est_phid1& 2.11e-01 & 0.071 & 1.78e-03
# est_phid2& 2.23e-01 & 0.112 & 5.62e-03
# est_phid3& 2.87e-01 & 0.315 & 5.62e-02

# %%
fig, ax= plt.subplots(1,1, figsize=(textwidth ,3.0))
for i in range(nrange):
    # ax=PL_decay.semiply(
    #     windows_cen-rmp_time, dpreds[i], ax=ax,
    #     color=f"C{i}",linestyle="-", label=f"Ref/Init{i+1}"
    #     )
    ax = PL_decay.semiply(
        windows_cen-rmp_time, dpreds_phid[i], ax=ax,
        color=f"C{i}",linestyle="-", label=f"Range{i} phid"
        )
ax=PL_decay.semiply(
    windows_cen-rmp_time, dobs, ax=ax, marker="o",markersize=3.0,
    color=f"C{nrange}",linestyle="", label="observation"
    )
ax = PL_decay.pl_axes(ax)

ax.legend()
ax.set_xlabel("Time (s)")
ax.set_ylabel("EMF (V/A)")
# Out:
# Text(0, 0.5, 'EMF (V/A)')

# %% [markdown]
# # get SIP of target layer

# %%
freq_step_log  = 0.1
freq_cmb = []
freq_mins = []
freq_maxs = []
for i in range(nrange):

    nfreq = int((taus_end_log[i] - taus_strt_log[i])/freq_step_log) +1
    freq = np.logspace(
        -taus_end_log[i], -taus_strt_log[i], nfreq, endpoint=True
        ) 
    # freq = 10**np.arange(-taus_end_log[i], -taus_strt_log[i]+freq_step_log, freq_step_log)
    freq /= 2.0*np.pi
    freq_cmb.append(freq)
    freq_mins.append(freq.min())
    freq_maxs.append(freq.max())
    print(f"Range {i}: nfreq {nfreq}, freq min {freq.min():.2e}, max {freq.max():.2e}")
# Out:
# Range 0: nfreq 8, freq min 8.95e+01, max 5.03e+02
# Range 1: nfreq 13, freq min 2.83e+01, max 5.03e+02
# Range 2: nfreq 23, freq min 2.83e+00, max 5.03e+02

# %%
freq_ext = 10.**np.arange(-1,5.1,0.1)   
IP_model = Pelton_res_f(freq=freq_ext)
sim_sip_pel_ext = InducedPolarizationSimulation(ip_model=IP_model, mode='sip')

# %%
noise_floor_ratio = 1e-3
niter = 100
stol=1e-6
coolingFactor = 2 # np.sqrt(2) 
coolingRate = 2
mu=1e-3
beta0_ratio = 1.0

# %%
sip_trues =[]
sim_sip_dd = []
sim_sip_dd_ext = []
sim_sip_pelton = []
sip_dpreds = []
model_recs_sip = []
dpreds_sip = []
error_prgs_sip = []
model_prgs_sip = []
dinit_refs_sip = []
data_prgs_sip =[]
betas_prgs_sip = []

for i in range(nrange):
    freq = freq_cmb[i]
    nfreq = len(freq)

    IP_model = Pelton_res_f(freq=freq)
    sim = InducedPolarizationSimulation(ip_model=IP_model, mode='sip')
    sim_sip_pelton.append(sim)
    dobs_sip = sim.dpred(m=mvec_obs)
    sip_trues.append(dobs_sip)
    f_abs = abs(IP_model.f(mvec_obs))
    noise_floor= f_abs.max()*noise_floor_ratio

    taus = taus_cmb[i]
    ntau = ntau_cmb[i]

    IP_model = DDR_f(freq=freq_ext,taus=taus)
    sim = InducedPolarizationSimulation(ip_model=IP_model, mode='sip')
    sim_sip_dd_ext.append(sim)

    IP_model = DDR_f(freq=freq,taus=taus)
    sim = InducedPolarizationSimulation(ip_model=IP_model, mode='sip')
    sim_sip_dd.append(sim)
    sip_dpreds.append(sim.dpred(models_rec_phid[i]))
    
    mvec_ref = m_refs[i]
    opt = Optimization(sim=sim, dobs= dobs_sip, Ws_threshold=Ws_threshold, alphas=alphas)
    opt.get_Wd(ratio=relative_error, plateau=noise_floor)
    opt.get_Ws(np.ones(len(mvec_ref)))
    beta0 = opt.BetaEstimate_byEig(mvec=mvec_ref, update_Wsen=True)
    mpred = opt.GaussNewton(
        mvec_init=mvec_ref,niter=niter,beta0=beta0, update_Wsen=True,
        stol=stol,mu=mu,coolingRate=coolingRate, coolingFactor=coolingFactor
        )
    dinit_refs_sip.append(opt.dpred(mvec_ref))
    model_recs_sip.append(mpred)
    dpreds_sip.append(opt.dpred(mpred))
    error_prgs_sip.append(opt.error_prg)
    model_prgs_sip.append(opt.mvec_prg)
    data_prgs_sip.append(opt.data_prg)
    betas_prgs_sip.append(opt.betas)
# Out:
#   1, beta:3.2e+08, step:1.0e+00, g:8.7e+04, phid:3.4e+03, phim:4.9e-08, f:3.4e+03
#   2, beta:3.2e+08, step:9.5e-07, g:8.6e+01, phid:3.4e+03, phim:4.9e-08, f:3.4e+03
#   3, beta:1.6e+08, step:1.0e+00, g:4.3e+04, phid:3.4e+03, phim:1.9e-07, f:3.4e+03
#   4, beta:1.6e+08, step:9.5e-07, g:8.3e+01, phid:3.4e+03, phim:1.9e-07, f:3.4e+03
#   5, beta:8.1e+07, step:1.0e+00, g:4.3e+04, phid:3.2e+03, phim:7.2e-07, f:3.3e+03
#   6, beta:8.1e+07, step:9.5e-07, g:1.6e+02, phid:3.2e+03, phim:7.2e-07, f:3.3e+03
#   7, beta:4.1e+07, step:1.0e+00, g:4.1e+04, phid:3.0e+03, phim:2.6e-06, f:3.1e+03
#   8, beta:4.1e+07, step:9.5e-07, g:2.8e+02, phid:3.0e+03, phim:2.6e-06, f:3.1e+03
#   9, beta:2.0e+07, step:1.0e+00, g:3.9e+04, phid:2.7e+03, phim:8.9e-06, f:2.9e+03
#  10, beta:2.0e+07, step:9.5e-07, g:4.5e+02, phid:2.7e+03, phim:8.9e-06, f:2.9e+03
#  11, beta:1.0e+07, step:1.0e+00, g:3.6e+04, phid:2.2e+03, phim:2.7e-05, f:2.5e+03
#  12, beta:1.0e+07, step:9.5e-07, g:6.2e+02, phid:2.2e+03, phim:2.7e-05, f:2.5e+03
#  13, beta:5.1e+06, step:1.0e+00, g:3.1e+04, phid:1.7e+03, phim:6.8e-05, f:2.0e+03
#  14, beta:5.1e+06, step:9.5e-07, g:7.0e+02, phid:1.7e+03, phim:6.8e-05, f:2.0e+03
#  15, beta:2.5e+06, step:1.0e+00, g:2.4e+04, phid:1.1e+03, phim:1.4e-04, f:1.5e+03
#  16, beta:2.5e+06, step:9.5e-07, g:6.4e+02, phid:1.1e+03, phim:1.4e-04, f:1.5e+03
#  17, beta:1.3e+06, step:1.0e+00, g:1.7e+04, phid:7.3e+02, phim:2.6e-04, f:1.1e+03
#  18, beta:1.3e+06, step:9.5e-07, g:4.7e+02, phid:7.3e+02, phim:2.6e-04, f:1.1e+03
#  19, beta:6.3e+05, step:1.0e+00, g:1.1e+04, phid:4.3e+02, phim:4.4e-04, f:7.1e+02
#  20, beta:6.3e+05, step:9.5e-07, g:2.8e+02, phid:4.3e+02, phim:4.4e-04, f:7.1e+02
#  21, beta:3.2e+05, step:1.0e+00, g:6.4e+03, phid:2.3e+02, phim:6.7e-04, f:4.5e+02
#  22, beta:3.2e+05, step:9.5e-07, g:1.5e+02, phid:2.3e+02, phim:6.7e-04, f:4.5e+02
#  23, beta:1.6e+05, step:1.0e+00, g:3.8e+03, phid:1.2e+02, phim:9.5e-04, f:2.7e+02
#  24, beta:1.6e+05, step:9.5e-07, g:1.0e+02, phid:1.2e+02, phim:9.6e-04, f:2.7e+02
#  25, beta:7.9e+04, step:1.0e+00, g:2.2e+03, phid:6.0e+01, phim:1.2e-03, f:1.6e+02
#  26, beta:7.9e+04, step:9.5e-07, g:5.8e+01, phid:6.0e+01, phim:1.3e-03, f:1.6e+02
#  27, beta:4.0e+04, step:1.0e+00, g:1.2e+03, phid:3.1e+01, phim:1.5e-03, f:9.1e+01
#  28, beta:4.0e+04, step:9.5e-07, g:3.0e+01, phid:3.1e+01, phim:1.5e-03, f:9.2e+01
#  29, beta:2.0e+04, step:1.0e+00, g:6.6e+02, phid:1.8e+01, phim:1.8e-03, f:5.3e+01
#  30, beta:2.0e+04, step:9.5e-07, g:1.3e+01, phid:1.8e+01, phim:1.8e-03, f:5.4e+01
#  31, beta:9.9e+03, step:1.0e+00, g:3.5e+02, phid:1.2e+01, phim:2.0e-03, f:3.2e+01
#  32, beta:9.9e+03, step:9.5e-07, g:4.9e+00, phid:1.2e+01, phim:2.0e-03, f:3.2e+01
#  33, beta:4.9e+03, step:1.0e+00, g:1.9e+02, phid:9.3e+00, phim:2.3e-03, f:2.1e+01
#  34, beta:4.9e+03, step:9.5e-07, g:1.5e+03, phid:9.3e+00, phim:2.4e-03, f:2.1e+01
#  35, beta:2.5e+03, step:2.5e-01, g:1.5e+03, phid:1.1e+01, phim:2.4e-03, f:1.7e+01
#  36, beta:2.5e+03, step:9.5e-07, g:2.5e+03, phid:1.1e+01, phim:2.5e-03, f:1.7e+01
#  37, beta:1.2e+03, step:1.2e-01, g:2.5e+03, phid:1.4e+01, phim:2.5e-03, f:1.7e+01
#  38, beta:1.2e+03, step:9.5e-07, g:3.3e+03, phid:1.4e+01, phim:2.6e-03, f:1.7e+01
#  39, beta:6.2e+02, step:6.2e-02, g:3.3e+03, phid:1.5e+01, phim:2.6e-03, f:1.7e+01
#  40, beta:6.2e+02, step:9.5e-07, g:3.6e+03, phid:1.5e+01, phim:2.6e-03, f:1.7e+01
#  41, beta:3.1e+02, step:1.2e-01, g:3.6e+03, phid:1.6e+01, phim:2.8e-03, f:1.7e+01
#  42, beta:3.1e+02, step:9.5e-07, g:3.9e+03, phid:1.6e+01, phim:2.8e-03, f:1.7e+01
#  43, beta:1.5e+02, step:6.2e-02, g:3.9e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  44, beta:1.5e+02, step:7.8e-03, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  45, beta:7.7e+01, step:9.8e-04, g:3.6e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  46, beta:7.7e+01, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  47, beta:3.9e+01, step:2.4e-04, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  48, beta:3.9e+01, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  49, beta:1.9e+01, step:1.2e-04, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  50, beta:1.9e+01, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  51, beta:9.7e+00, step:6.1e-05, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  52, beta:9.7e+00, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  53, beta:4.8e+00, step:3.1e-05, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  54, beta:4.8e+00, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  55, beta:2.4e+00, step:1.5e-05, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  56, beta:2.4e+00, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  57, beta:1.2e+00, step:7.6e-06, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  58, beta:1.2e+00, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  59, beta:6.0e-01, step:3.8e-06, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  60, beta:6.0e-01, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  61, beta:3.0e-01, step:1.9e-06, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  62, beta:3.0e-01, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  63, beta:1.5e-01, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  64, beta:1.5e-01, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  65, beta:7.6e-02, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  66, beta:7.6e-02, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  67, beta:3.8e-02, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  68, beta:3.8e-02, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  69, beta:1.9e-02, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  70, beta:1.9e-02, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  71, beta:9.4e-03, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  72, beta:9.4e-03, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  73, beta:4.7e-03, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  74, beta:4.7e-03, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  75, beta:2.4e-03, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  76, beta:2.4e-03, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  77, beta:1.2e-03, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  78, beta:1.2e-03, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  79, beta:5.9e-04, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  80, beta:5.9e-04, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  81, beta:3.0e-04, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  82, beta:3.0e-04, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  83, beta:1.5e-04, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  84, beta:1.5e-04, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  85, beta:7.4e-05, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  86, beta:7.4e-05, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  87, beta:3.7e-05, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  88, beta:3.7e-05, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  89, beta:1.8e-05, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  90, beta:1.8e-05, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  91, beta:9.2e-06, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  92, beta:9.2e-06, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  93, beta:4.6e-06, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  94, beta:4.6e-06, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  95, beta:2.3e-06, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  96, beta:2.3e-06, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  97, beta:1.2e-06, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  98, beta:1.2e-06, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#  99, beta:5.8e-07, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
# 100, beta:5.8e-07, step:9.5e-07, g:3.7e+03, phid:1.4e+01, phim:2.9e-03, f:1.4e+01
#   1, beta:3.4e+08, step:1.0e+00, g:1.2e+05, phid:5.7e+03, phim:1.1e-07, f:5.7e+03
#   2, beta:3.4e+08, step:1.6e-02, g:1.5e+02, phid:5.7e+03, phim:1.1e-07, f:5.7e+03
#   3, beta:1.7e+08, step:1.0e+00, g:6.1e+04, phid:5.5e+03, phim:4.2e-07, f:5.6e+03
#   4, beta:1.7e+08, step:1.6e-02, g:1.5e+02, phid:5.5e+03, phim:4.2e-07, f:5.6e+03
#   5, beta:8.4e+07, step:1.0e+00, g:6.0e+04, phid:5.3e+03, phim:1.6e-06, f:5.4e+03
#   6, beta:8.4e+07, step:1.6e-02, g:2.7e+02, phid:5.3e+03, phim:1.6e-06, f:5.4e+03
#   7, beta:4.2e+07, step:1.0e+00, g:5.8e+04, phid:4.8e+03, phim:5.6e-06, f:5.0e+03
#   8, beta:4.2e+07, step:1.6e-02, g:4.7e+02, phid:4.8e+03, phim:5.6e-06, f:5.0e+03
#   9, beta:2.1e+07, step:1.0e+00, g:5.4e+04, phid:4.1e+03, phim:1.8e-05, f:4.5e+03
#  10, beta:2.1e+07, step:4.9e-04, g:7.1e+02, phid:4.1e+03, phim:1.8e-05, f:4.5e+03
#  11, beta:1.1e+07, step:1.0e+00, g:4.8e+04, phid:3.2e+03, phim:5.0e-05, f:3.7e+03
#  12, beta:1.1e+07, step:9.5e-07, g:8.9e+02, phid:3.2e+03, phim:5.0e-05, f:3.7e+03
#  13, beta:5.3e+06, step:1.0e+00, g:3.9e+04, phid:2.2e+03, phim:1.2e-04, f:2.8e+03
#  14, beta:5.3e+06, step:9.5e-07, g:9.0e+02, phid:2.2e+03, phim:1.2e-04, f:2.8e+03
#  15, beta:2.6e+06, step:1.0e+00, g:2.9e+04, phid:1.4e+03, phim:2.3e-04, f:2.0e+03
#  16, beta:2.6e+06, step:9.5e-07, g:7.3e+02, phid:1.4e+03, phim:2.3e-04, f:2.0e+03
#  17, beta:1.3e+06, step:1.0e+00, g:1.9e+04, phid:8.8e+02, phim:3.9e-04, f:1.4e+03
#  18, beta:1.3e+06, step:9.5e-07, g:5.0e+02, phid:8.8e+02, phim:3.9e-04, f:1.4e+03
#  19, beta:6.6e+05, step:1.0e+00, g:1.2e+04, phid:5.0e+02, phim:6.1e-04, f:9.0e+02
#  20, beta:6.6e+05, step:9.5e-07, g:3.0e+02, phid:5.0e+02, phim:6.2e-04, f:9.1e+02
#  21, beta:3.3e+05, step:1.0e+00, g:6.9e+03, phid:2.6e+02, phim:8.9e-04, f:5.6e+02
#  22, beta:3.3e+05, step:9.5e-07, g:1.7e+02, phid:2.6e+02, phim:9.0e-04, f:5.6e+02
#  23, beta:1.6e+05, step:1.0e+00, g:3.9e+03, phid:1.3e+02, phim:1.2e-03, f:3.3e+02
#  24, beta:1.6e+05, step:9.5e-07, g:1.1e+02, phid:1.3e+02, phim:1.2e-03, f:3.3e+02
#  25, beta:8.2e+04, step:1.0e+00, g:2.1e+03, phid:6.3e+01, phim:1.5e-03, f:1.9e+02
#  26, beta:8.2e+04, step:9.5e-07, g:6.1e+01, phid:6.3e+01, phim:1.5e-03, f:1.9e+02
#  27, beta:4.1e+04, step:1.0e+00, g:1.2e+03, phid:3.1e+01, phim:1.8e-03, f:1.1e+02
#  28, beta:4.1e+04, step:9.5e-07, g:2.9e+01, phid:3.1e+01, phim:1.8e-03, f:1.1e+02
#  29, beta:2.1e+04, step:1.0e+00, g:6.1e+02, phid:1.6e+01, phim:2.1e-03, f:5.9e+01
#  30, beta:2.1e+04, step:9.5e-07, g:1.1e+01, phid:1.6e+01, phim:2.1e-03, f:5.9e+01
#  31, beta:1.0e+04, step:1.0e+00, g:3.2e+02, phid:9.1e+00, phim:2.3e-03, f:3.3e+01
#  32, beta:1.0e+04, step:9.5e-07, g:3.6e+00, phid:9.1e+00, phim:2.3e-03, f:3.3e+01
#  33, beta:5.2e+03, step:1.0e+00, g:1.7e+02, phid:5.9e+00, phim:2.6e-03, f:1.9e+01
#  34, beta:5.2e+03, step:9.5e-07, g:4.0e+02, phid:5.9e+00, phim:2.6e-03, f:1.9e+01
#  35, beta:2.6e+03, step:1.0e+00, g:3.5e+02, phid:6.9e+00, phim:2.8e-03, f:1.4e+01
#  36, beta:2.6e+03, step:9.5e-07, g:2.4e+03, phid:6.9e+00, phim:2.8e-03, f:1.4e+01
#  37, beta:1.3e+03, step:1.0e+00, g:2.4e+03, phid:6.2e+00, phim:3.2e-03, f:1.0e+01
#  38, beta:1.3e+03, step:1.0e+00, g:2.5e+03, phid:6.1e+00, phim:3.1e-03, f:1.0e+01
#  39, beta:6.4e+02, step:1.2e-01, g:2.5e+03, phid:6.8e+00, phim:3.2e-03, f:8.8e+00
#  40, beta:6.4e+02, step:9.5e-07, g:2.8e+03, phid:6.8e+00, phim:3.2e-03, f:8.8e+00
#  41, beta:3.2e+02, step:1.6e-02, g:2.8e+03, phid:7.6e+00, phim:3.2e-03, f:8.6e+00
#  42, beta:3.2e+02, step:9.5e-07, g:3.0e+03, phid:7.6e+00, phim:3.2e-03, f:8.6e+00
#  43, beta:1.6e+02, step:3.9e-03, g:3.0e+03, phid:8.0e+00, phim:3.2e-03, f:8.5e+00
#  44, beta:1.6e+02, step:9.5e-07, g:3.1e+03, phid:8.0e+00, phim:3.2e-03, f:8.5e+00
#  45, beta:8.0e+01, step:9.8e-04, g:3.1e+03, phid:8.1e+00, phim:3.2e-03, f:8.4e+00
#  46, beta:8.0e+01, step:9.5e-07, g:3.2e+03, phid:8.1e+00, phim:3.2e-03, f:8.4e+00
#  47, beta:4.0e+01, step:4.9e-04, g:3.2e+03, phid:8.2e+00, phim:3.2e-03, f:8.4e+00
#  48, beta:4.0e+01, step:9.5e-07, g:3.2e+03, phid:8.2e+00, phim:3.2e-03, f:8.4e+00
#  49, beta:2.0e+01, step:2.4e-04, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.4e+00
#  50, beta:2.0e+01, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.4e+00
#  51, beta:1.0e+01, step:6.1e-05, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  52, beta:1.0e+01, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  53, beta:5.0e+00, step:3.1e-05, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  54, beta:5.0e+00, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  55, beta:2.5e+00, step:1.5e-05, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  56, beta:2.5e+00, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  57, beta:1.3e+00, step:7.6e-06, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  58, beta:1.3e+00, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  59, beta:6.3e-01, step:3.8e-06, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  60, beta:6.3e-01, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  61, beta:3.1e-01, step:1.9e-06, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  62, beta:3.1e-01, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  63, beta:1.6e-01, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  64, beta:1.6e-01, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  65, beta:7.9e-02, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  66, beta:7.9e-02, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  67, beta:3.9e-02, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  68, beta:3.9e-02, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  69, beta:2.0e-02, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  70, beta:2.0e-02, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  71, beta:9.8e-03, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  72, beta:9.8e-03, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  73, beta:4.9e-03, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  74, beta:4.9e-03, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  75, beta:2.5e-03, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  76, beta:2.5e-03, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  77, beta:1.2e-03, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  78, beta:1.2e-03, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  79, beta:6.1e-04, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  80, beta:6.1e-04, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  81, beta:3.1e-04, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  82, beta:3.1e-04, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  83, beta:1.5e-04, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  84, beta:1.5e-04, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  85, beta:7.7e-05, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  86, beta:7.7e-05, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  87, beta:3.8e-05, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  88, beta:3.8e-05, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  89, beta:1.9e-05, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  90, beta:1.9e-05, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  91, beta:9.6e-06, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  92, beta:9.6e-06, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  93, beta:4.8e-06, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  94, beta:4.8e-06, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  95, beta:2.4e-06, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  96, beta:2.4e-06, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  97, beta:1.2e-06, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  98, beta:1.2e-06, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#  99, beta:6.0e-07, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
# 100, beta:6.0e-07, step:9.5e-07, g:3.2e+03, phid:8.3e+00, phim:3.2e-03, f:8.3e+00
#   1, beta:1.9e+08, step:1.0e+00, g:1.5e+05, phid:9.4e+03, phim:7.6e-07, f:9.5e+03
#   2, beta:1.9e+08, step:6.2e-02, g:3.4e+02, phid:9.4e+03, phim:7.6e-07, f:9.5e+03
#   3, beta:9.6e+07, step:1.0e+00, g:7.4e+04, phid:8.9e+03, phim:2.8e-06, f:9.1e+03
#   4, beta:9.6e+07, step:3.1e-02, g:3.0e+02, phid:8.9e+03, phim:2.8e-06, f:9.1e+03
#   5, beta:4.8e+07, step:1.0e+00, g:7.2e+04, phid:7.9e+03, phim:1.0e-05, f:8.4e+03
#   6, beta:4.8e+07, step:3.1e-02, g:5.2e+02, phid:7.9e+03, phim:1.0e-05, f:8.4e+03
#   7, beta:2.4e+07, step:1.0e+00, g:6.7e+04, phid:6.5e+03, phim:3.2e-05, f:7.3e+03
#   8, beta:2.4e+07, step:3.1e-02, g:7.7e+02, phid:6.5e+03, phim:3.2e-05, f:7.3e+03
#   9, beta:1.2e+07, step:1.0e+00, g:5.9e+04, phid:4.7e+03, phim:8.7e-05, f:5.8e+03
#  10, beta:1.2e+07, step:1.6e-02, g:9.5e+02, phid:4.7e+03, phim:8.7e-05, f:5.8e+03
#  11, beta:6.0e+06, step:1.0e+00, g:4.8e+04, phid:2.9e+03, phim:2.0e-04, f:4.1e+03
#  12, beta:6.0e+06, step:9.5e-07, g:9.2e+02, phid:2.9e+03, phim:2.0e-04, f:4.1e+03
#  13, beta:3.0e+06, step:1.0e+00, g:3.5e+04, phid:1.6e+03, phim:3.6e-04, f:2.7e+03
#  14, beta:3.0e+06, step:9.5e-07, g:6.9e+02, phid:1.6e+03, phim:3.6e-04, f:2.7e+03
#  15, beta:1.5e+06, step:1.0e+00, g:2.3e+04, phid:8.0e+02, phim:5.5e-04, f:1.6e+03
#  16, beta:1.5e+06, step:9.5e-07, g:4.3e+02, phid:8.0e+02, phim:5.5e-04, f:1.6e+03
#  17, beta:7.5e+05, step:1.0e+00, g:1.4e+04, phid:3.8e+02, phim:7.5e-04, f:9.5e+02
#  18, beta:7.5e+05, step:9.5e-07, g:2.3e+02, phid:3.8e+02, phim:7.6e-04, f:9.5e+02
#  19, beta:3.7e+05, step:1.0e+00, g:7.6e+03, phid:1.7e+02, phim:9.6e-04, f:5.3e+02
#  20, beta:3.7e+05, step:9.5e-07, g:1.1e+02, phid:1.7e+02, phim:9.6e-04, f:5.3e+02
#  21, beta:1.9e+05, step:1.0e+00, g:4.1e+03, phid:7.1e+01, phim:1.2e-03, f:2.9e+02
#  22, beta:1.9e+05, step:9.5e-07, g:5.5e+01, phid:7.1e+01, phim:1.2e-03, f:2.9e+02
#  23, beta:9.4e+04, step:1.0e+00, g:2.2e+03, phid:3.0e+01, phim:1.3e-03, f:1.5e+02
#  24, beta:9.4e+04, step:9.5e-07, g:2.5e+01, phid:3.0e+01, phim:1.3e-03, f:1.5e+02
#  25, beta:4.7e+04, step:1.0e+00, g:1.1e+03, phid:1.3e+01, phim:1.4e-03, f:8.1e+01
#  26, beta:4.7e+04, step:9.5e-07, g:9.4e+00, phid:1.3e+01, phim:1.4e-03, f:8.1e+01
#  27, beta:2.3e+04, step:1.0e+00, g:5.9e+02, phid:6.8e+00, phim:1.5e-03, f:4.3e+01
#  28, beta:2.3e+04, step:9.5e-07, g:3.0e+00, phid:6.8e+00, phim:1.5e-03, f:4.3e+01
#  29, beta:1.2e+04, step:1.0e+00, g:3.0e+02, phid:3.9e+00, phim:1.6e-03, f:2.3e+01
#  30, beta:1.2e+04, step:1.0e+00, g:1.0e+00, phid:3.9e+00, phim:1.6e-03, f:2.3e+01
#  31, beta:5.9e+03, step:1.0e+00, g:1.5e+02, phid:2.5e+00, phim:1.7e-03, f:1.2e+01
#  32, beta:5.9e+03, step:1.0e+00, g:5.0e-01, phid:2.5e+00, phim:1.7e-03, f:1.2e+01
#  33, beta:2.9e+03, step:1.0e+00, g:7.6e+01, phid:1.7e+00, phim:1.8e-03, f:7.0e+00
#  34, beta:2.9e+03, step:1.0e+00, g:3.1e-01, phid:1.7e+00, phim:1.8e-03, f:7.0e+00
#  35, beta:1.5e+03, step:1.0e+00, g:3.9e+01, phid:1.1e+00, phim:1.9e-03, f:4.0e+00
#  36, beta:1.5e+03, step:1.0e+00, g:2.3e-01, phid:1.1e+00, phim:1.9e-03, f:4.0e+00
#  37, beta:7.3e+02, step:1.0e+00, g:2.0e+01, phid:7.8e-01, phim:2.1e-03, f:2.3e+00
#  38, beta:7.3e+02, step:1.0e+00, g:2.0e-01, phid:7.7e-01, phim:2.1e-03, f:2.3e+00
#  39, beta:3.7e+02, step:2.5e-01, g:1.0e+01, phid:7.0e-01, phim:2.2e-03, f:1.5e+00
#  40, beta:3.7e+02, step:6.2e-02, g:7.7e+00, phid:6.9e-01, phim:2.2e-03, f:1.5e+00
#  41, beta:1.8e+02, step:6.2e-02, g:1.2e+01, phid:9.7e-01, phim:2.2e-03, f:1.4e+00
#  42, beta:1.8e+02, step:9.5e-07, g:5.0e+02, phid:9.7e-01, phim:2.2e-03, f:1.4e+00
#  43, beta:9.1e+01, step:7.8e-03, g:5.0e+02, phid:1.1e+00, phim:2.2e-03, f:1.3e+00
#  44, beta:9.1e+01, step:9.5e-07, g:6.1e+02, phid:1.1e+00, phim:2.2e-03, f:1.3e+00
#  45, beta:4.6e+01, step:2.0e-03, g:6.1e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  46, beta:4.6e+01, step:9.5e-07, g:6.5e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  47, beta:2.3e+01, step:9.8e-04, g:6.5e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  48, beta:2.3e+01, step:9.5e-07, g:6.8e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  49, beta:1.1e+01, step:4.9e-04, g:6.8e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  50, beta:1.1e+01, step:9.5e-07, g:6.9e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  51, beta:5.7e+00, step:1.2e-04, g:6.9e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  52, beta:5.7e+00, step:9.5e-07, g:7.0e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  53, beta:2.9e+00, step:6.1e-05, g:7.0e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  54, beta:2.9e+00, step:9.5e-07, g:7.0e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  55, beta:1.4e+00, step:3.1e-05, g:7.0e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  56, beta:1.4e+00, step:9.5e-07, g:7.0e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  57, beta:7.1e-01, step:1.5e-05, g:7.0e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  58, beta:7.1e-01, step:9.5e-07, g:7.0e+02, phid:1.2e+00, phim:2.2e-03, f:1.3e+00
#  59, beta:3.6e-01, step:7.6e-06, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  60, beta:3.6e-01, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  61, beta:1.8e-01, step:3.8e-06, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  62, beta:1.8e-01, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  63, beta:8.9e-02, step:1.9e-06, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  64, beta:8.9e-02, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  65, beta:4.5e-02, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  66, beta:4.5e-02, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  67, beta:2.2e-02, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  68, beta:2.2e-02, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  69, beta:1.1e-02, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  70, beta:1.1e-02, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  71, beta:5.6e-03, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  72, beta:5.6e-03, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  73, beta:2.8e-03, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  74, beta:2.8e-03, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  75, beta:1.4e-03, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  76, beta:1.4e-03, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  77, beta:7.0e-04, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  78, beta:7.0e-04, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  79, beta:3.5e-04, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  80, beta:3.5e-04, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  81, beta:1.7e-04, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  82, beta:1.7e-04, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  83, beta:8.7e-05, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  84, beta:8.7e-05, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  85, beta:4.4e-05, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  86, beta:4.4e-05, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  87, beta:2.2e-05, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  88, beta:2.2e-05, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  89, beta:1.1e-05, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  90, beta:1.1e-05, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  91, beta:5.4e-06, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  92, beta:5.4e-06, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  93, beta:2.7e-06, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  94, beta:2.7e-06, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  95, beta:1.4e-06, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  96, beta:1.4e-06, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  97, beta:6.8e-07, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  98, beta:6.8e-07, step:9.5e-07, g:7.0e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
#  99, beta:3.4e-07, step:9.5e-07, g:7.1e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00
# 100, beta:3.4e-07, step:9.5e-07, g:7.1e+02, phid:1.3e+00, phim:2.2e-03, f:1.3e+00

# %%
phid_star_ratio = 1.1
sip_true_inv = []
sip_true_dpred = []
for i in range(nrange):
    sim = sim_sip_dd[i]
    freq = freq_cmb[i]
    taus = taus_cmb[i]
    nfreq = freq.shape[0]
    phid_star = nfreq*2
    model_prg= np.array(model_prgs_sip[i])
    data_prg = np.array(data_prgs_sip[i])
    error_prg = error_prgs_sip[i]
    phid_prg = np.array(error_prg)[:,1]
    ind = phid_prg < phid_star*phid_star_ratio
    if np.sum(ind) == 0:
        ind = phid_prg == np.min(phid_prg)
        print(f" range {i}:No phid star found, take min phid")
    sip_true_inv.append(model_prg[ind][0])
    model = model_prg[ind][0]
    sip_true_dpred.append(data_prg[ind][0])
    rho0_sip = np.exp(model[0])
    eta_sip = model[1:].sum()
    print(f"Model {i}: rho0: {rho0_sip:.2e}, eta: {eta_sip:.3f}")
# Out:
# Model 0: rho0: 2.04e-01, eta: 0.088
# Model 1: rho0: 2.17e-01, eta: 0.140
# Model 2: rho0: 2.57e-01, eta: 0.257

# %%
def plot_etas_model(model,taus, ax=None, **kwargs):
    if ax is None: 
        fig, ax = plt.subplots(1, 1, figsize=(5,3))
    etas = model[1:]

    ax.semilogx(taus, etas, **kwargs)
    ax.set_xlabel(r"$\tau_k$ [s]")
    ax.set_ylabel(r"$\eta_k$")
    return ax

# %%
# title_heads= ['model_1', 'model_2', 'model_3']
# title_heads = []
# for i in range(nrange):
#     title_head = fr'$max(\tau_k)$: {taus_end[i]:.1e}'
#     title_heads.append(title_head)
title_heads = [r"$\tau_k$ band_1", r"$\tau_k$ band_2", r"$\tau_k$ band_3"]

print(title_heads)
column_labels = ["1", "2", "3"]
# Out:
# ['$\\tau_k$ band_1', '$\\tau_k$ band_2', '$\\tau_k$ band_3']

# %%
plt.style.use('00_figures.mplstyle')

# %%
fig, ax = plt.subplots(
    3, nrange, sharex='row', sharey='row',
    figsize=(textwidth ,5.5), #  constrained_layout=True,  
    gridspec_kw={"width_ratios": [1.0, 1.0, 1],
                 "height_ratios": [1.5, 1.0, 1.0]
                }  # key line
)

ax_ranges = []
for i in range(nrange):
    ax_ranges.append([ax[0, i], ax[1, i], ax[2, i]])

for i in range(nrange):
    title_head= title_heads[i]
    phid_itr = phid_itrs[i]
    model = models_rec_phid[i]

    sim_pelton = sim_sip_pelton[i]
    ax_range = ax_ranges[i]
    axdata = ax_range[0]
    axsip = [ax_range[1], ax_range[2]]
    axdata = plot_data(data_init = dinit_refs[i], dpred=dpreds_phid[i], ax=axdata)

    sim = sim_sip_pel_ext 
    axsip = sim.plot_sip_model(model=mvec_obs, ax=axsip,
            color="C3", linestyle="-.", alpha=0.7)
    sim = sim_sip_dd_ext[i]
    axsip= sim.plot_sip_model(model=model, ax=axsip,
            color="C0", linestyle="-.", alpha=0.7 )
    sim = sim_sip_pelton[i]
    axsip = sim.plot_sip_model(model=mvec_obs, ax=axsip,
            color="C3", label=f"True", linestyle="-")
    

    sim = sim_sip_dd[i]
    axsip = sim.plot_sip_model(model=model, ax=axsip,
            color="C0", label=f"Est", linestyle="-")

    axsip[0].axvline(x=freq_mins[i], color='k', linestyle='--', linewidth=1.0,
                     label=f"range_rec"
                     )
    axsip[0].axvline(x=freq_maxs[i], color='k', linestyle='--', linewidth=1.0)
    axsip[1].axvline(x=freq_mins[i], color='k', linestyle='--', linewidth=1.0,
                     label=f"range_rec"
                     )
    axsip[1].axvline(x=freq_maxs[i], color='k', linestyle='--', linewidth=1.0)

    axsip[0].invert_xaxis()
    axsip[1].invert_xaxis()
    axsip[1].invert_yaxis()

    if i == nrange-1:
        title = (
            'Data_Plot \n' +
            rf'$\varepsilon_{{rel}}$ {relative_error*100:.1f} %' + '\n' +
            rf'$\varepsilon_{{floor}}: {fmt(data_noise_floor,prec=1)} $'
        )
        axdata.legend(title=title,loc="upper left", bbox_to_anchor=(1.1,1))
        title = 'SIP_amp'
        axsip[0].legend(title=title,loc="upper left", bbox_to_anchor=(1.1,1))
        title = 'SIP_Phs'
        axsip[1].legend(title=title,loc="upper left", bbox_to_anchor=(1.1,1))

    ax_range[0].set_title(f"{title_head}_Data")
    ax_range[1].set_title(f"{title_head}_SIP_amp")
    ax_range[2].set_title(f"{title_head}_SIP_phs")
    column_label = column_labels[i]
    low_names= ['-a', '-b', '-c']

    for label, axis in zip(low_names, ax_range):
        axis.text(
            -0.1, 1.1, f"{column_label}{label}",   # ✅ inside axes
             transform=axis.transAxes,
        fontweight="bold",
        va="top", ha="left"
    )

for acol in ax[:, 1:nrange]:
    for a in acol:
        a.tick_params(labelleft=False)
        a.set_ylabel("")
plt.savefig('../figures/43_DD_data_rec.png')
plt.savefig('../manuscript/figures/43_DD_data_rec.pdf')

# %%
fig, ax = plt.subplots(
    3, nrange, sharex='row', sharey='row',
    figsize=(textwidth ,4.0), #constrained_layout=True,  
    gridspec_kw={"width_ratios": [1.0, 1.0, 1],
                 "height_ratios": [1.0, 1.0, 1.0]
                }  # key line
)

ax_ranges = []
for i in range(nrange):
    ax_ranges.append([ax[0, i], ax[1, i], ax[2, i]])

for i in range(nrange):
    title_head = title_heads[i]
    ax_range = ax_ranges[i]
    axrm = ax_range[0:2]
    axetas = ax_range[2]
    sim = sim_sip_dd[i]
    m_ref = m_refs[i]
    linewidth = 1.0
    axrm = sim_inv[i].plot_IP_par(mvec=m_ref, rm=True,
        label="Ref/Init", color=f"C1", linestyle="-",
        ax=axrm, linewidth=linewidth)
    axrm = sim_inv[i].plot_IP_par(mvec=models_rec_phid[i], rm=True,
        label="TEM_inv", color=f"C0", linestyle="-", 
        ax=axrm, linewidth=linewidth)
    rho0,eta = sim.ip_model.get_rho_eta(models_rec_phid[i])
    # label = fr"Est $\rho_0$:{rho0: .1e},$\eta$:{eta: .2f}"
    marker, markersize = 'o', 2.0
    axetas = plot_etas_model(models_rec_phid[i], taus_cmb[i],
             ax=axetas, color="C0",
             label="TEM_inv",
            linestyle="-", marker=marker, markersize=markersize, linewidth=linewidth
             )
    axrm = sim_inv[i].plot_IP_par(mvec=sip_true_inv[i], rm=True,
            label="SIP_inv", color=f"C3", linestyle="--",
            ax=axrm, linewidth=linewidth)

    rho0,eta = sim.ip_model.get_rho_eta(sip_true_inv[i])
    # label = fr"Rec $\rho_0$:{rho0: .1e},$\eta$:{eta: .2f}"


    axetas = plot_etas_model(sip_true_inv[i], taus_cmb[i],
             ax=axetas, color="C3", label="SIP_inv",
             linestyle="--", linewidth=linewidth,
             marker=marker, markersize=markersize)
    axrm[0].invert_xaxis()
    axrm[0].set_xlim([1.2,0.09])
    axrm[1].set_xlim(right=0.4)
    axrm[0].set_title(fr"{title_head}_$\rho_0$")
    axrm[1].set_title(fr"{title_head}_$\sum\eta_k$")
    axetas.set_title(fr"{title_head}_$\eta_k$ vs $\tau_k$")
    label = fr"$\tau_\rho$" 
    axetas.axvline(x=tau_target, color='k', linestyle='--', linewidth=1.0,
                     label=label)
    for j , a in enumerate(axrm):  # Iterate over rows
        # a.axhline(empymod_model_sim["src"][4], color=f"C4", linestyle="-", label="Src+Rec")
        # a.set_ylim([12.5, -2.5])
        a.set_ylim([12.5, -2.5])
        a.set_ylabel('depth [m]')
        if j== 0:
            a.set_xscale("log")
        else:
            a.set_xscale("linear")

    if i == nrange-1:
        title=r"$\rho_0$"
        axrm[0].legend(title=title, loc="upper left", bbox_to_anchor=(1.1,1))
        title = r"$\sum\eta_k$"
        axrm[1].legend(title=title, loc="upper left", bbox_to_anchor=(1.1,1))
        title = r"$\eta_k$ vs $\tau_k$"
        axetas.legend(title=title, loc="upper left", bbox_to_anchor=(1.1,1))

    column_label = column_labels[i]

    for label, axis in zip(low_names, ax_range):
        axis.text(
            0.0, 1.2, f"{column_label}{label}",   # ✅ inside axes
             transform=axis.transAxes,
        fontweight="bold",
        va="top", ha="left"
    )
for acol in ax[:, 1:nrange]:
    for a in acol:
        a.tick_params(labelleft=False)
        a.set_ylabel("")
plt.savefig('../figures/43_Recovered_DD.png')
plt.savefig('../manuscript/figures/43_Recovered_DD.pdf')

# %%
ntau_print=[]
sip_inv_print=[]
tem_inv_print=[]
phid_print=[]
taurange_print = []
freqrange_print = []
for i in range(nrange):
    sip_inv_print.append(sip_true_inv[i])
    tem_inv_print.append(models_rec_phid[i])
    ntau_print.append(ntau_cmb[i])
    taurange_print.append(np.r_[taus_strt[i], taus_end[i]])
    freqrange_print.append(np.r_[freq_mins[i], freq_maxs[i]])

# %%
rho0_print =[]
eta_print =[]

rho0_print.append(np.exp(mvec_obs[0]))
eta_print.append(mvec_obs[1])

for i in range(nrange):
    model = np.array(tem_inv_print[i])
    rho0 = np.exp(model[0])
    eta = model[1:].sum()
    rho0_print.append(rho0)
    eta_print.append(eta)
    model = np.array(sip_inv_print[i])
    rho0 = np.exp(model[0])
    eta = model[1:].sum() 
    rho0_print.append(rho0)
    eta_print.append(eta)

names_print=[]
names_print.append("True")
for i in range(nrange):
    names_print.append(f"TEM inv")
    names_print.append(f"SIP inv")
titles_print=[]
for i in range(nrange):
    titles_print.append(rf"$\tau_k$-band {i+1}")

# %%
print(r" & & \multicolumn{2}{c|}{"
      + r"} & \multicolumn{2}{c|}{".join(f"{v}" for v in titles_print)
       + r"} \\"
)
print("\hline")
print(r" \multicolumn{2}{c|}{frequency band (\si{\hertz})} & \multicolumn{2}{c|}{\num{"
      + r"}} & \multicolumn{2}{c|}{\num{".join(
          r"} to \num{".join(f"{v:.1e}" for v in z)
          for z in freqrange_print)
       + r"}} \\"
)

print("\hline")

print(r" \multicolumn{2}{c|}{$\tau_k$ band (\si{\second})} & \multicolumn{2}{c|}{\num{"
      + r"}} & \multicolumn{2}{c|}{\num{".join(
          r"} to \num{".join(f"{v:.1e}" for v in z)
          for z in taurange_print)
       + r"}} \\"
)
print("\hline")

print(r"\multicolumn{2}{c|}{n} & \multicolumn{2}{c|}{\num{"
      +r"}} & \multicolumn{2}{c|}{\num{".join(f"{v:2.0f}" for v in ntau_print)
       + r"}} \\"
)

print(" & "
      +" & ".join(f"{v}" for v in names_print)
       + r"\\"
)

print(r"$\rho_0$ (\si{\Omega \meter})& \num{"
      +r"} & \num{".join(f"{v:4.2f}" for v in  rho0_print)
       + r"} \\"
)
print(r"$\eta$ & \num{"
      +r"} & \num{".join(f"{v:4.2f}" for v in eta_print)
     + r"} \\"
)
# Out:
#  & & \multicolumn{2}{c|}{$\tau_k$-band 1} & \multicolumn{2}{c|}{$\tau_k$-band 2} & \multicolumn{2}{c|}{$\tau_k$-band 3} \\
# \hline
#  \multicolumn{2}{c|}{frequency band (\si{\hertz})} & \multicolumn{2}{c|}{\num{8.9e+01} to \num{5.0e+02}} & \multicolumn{2}{c|}{\num{2.8e+01} to \num{5.0e+02}} & \multicolumn{2}{c|}{\num{2.8e+00} to \num{5.0e+02}} \\
# \hline
#  \multicolumn{2}{c|}{$\tau_k$ band (\si{\second})} & \multicolumn{2}{c|}{\num{3.2e-04} to \num{1.8e-03}} & \multicolumn{2}{c|}{\num{3.2e-04} to \num{5.6e-03}} & \multicolumn{2}{c|}{\num{3.2e-04} to \num{5.6e-02}} \\
# \hline
# \multicolumn{2}{c|}{n} & \multicolumn{2}{c|}{\num{ 4}} & \multicolumn{2}{c|}{\num{ 6}} & \multicolumn{2}{c|}{\num{10}} \\
#  & True & TEM inv & SIP inv & TEM inv & SIP inv & TEM inv & SIP inv\\
# $\rho_0$ (\si{\Omega \meter})& \num{0.30} & \num{0.21} & \num{0.20} & \num{0.22} & \num{0.22} & \num{0.29} & \num{0.26} \\
# $\eta$ & \num{0.40} & \num{0.07} & \num{0.09} & \num{0.11} & \num{0.14} & \num{0.31} & \num{0.26} \\

# %%
chis
# Out:
# [np.float64(6.573675839947575),
#  np.float64(1.0371448988629899),
#  np.float64(1.0471713565306784)]

# %%
fig, ax = plt.subplots(3, 3, figsize=(textwidth,4))
fig.set_constrained_layout_pads(
    h_pad=0.01,
    w_pad=0.01,
    hspace=0.02,
    wspace=0.02
)
ax_ranges = []
ax_ranges.append([ax[0, 0], ax[1, 0], ax[2, 0]])
ax_ranges.append([ax[0, 1], ax[1, 1], ax[2, 1]])
ax_ranges.append([ax[0, 2], ax[1, 2], ax[2, 2]])
for i in range(nrange):
    title_head = title_heads[i]
    ax_range = ax_ranges[i]
    axrm = ax_range[0:2]
    axetas = ax_range[2]
    sim = sim_sip_dd [i]
    m_ref = m_refs[i]
    axrm = sim_inv[i].plot_IP_par(mvec=m_ref, rm=True,
        label="Ref/Init", color=f"C1", linestyle="-",
        ax=axrm, linewidth=2.0)
    axrm = sim_inv[i].plot_IP_par(mvec=models_rec_phid[i], rm=True,
        label="Est", color=f"C0", linestyle="-", 
        ax=axrm, linewidth=2.0)
    rho0,eta = sim.ip_model.get_rho_eta(models_rec_phid[i])
    # label = fr"Est $\rho_0$:{rho0: .1e},$\eta$:{eta: .2f}"

    axetas = plot_etas_model(models_rec_phid[i], taus_cmb[i],
             ax=axetas, color="C0",
             label="Est",
            linestyle="-", marker='o', markersize=4
             )
    # axrm = sim_inv[i].plot_IP_par(mvec=sip_true_inv[i], rm=True,
    #         label="Reconciled", color=f"C2", linestyle=":",
    #         ax=axrm, linewidth=3.0)
    axrm = sim_obs.plot_IP_par(mvec=mvec_obs, rm=True,
            label="Pelton", color=f"C3", linestyle="--",
            ax=axrm, linewidth=2.0)

    rho0,eta = sim.ip_model.get_rho_eta(sip_true_inv[i])
    # label = fr"Rec $\rho_0$:{rho0: .1e},$\eta$:{eta: .2f}"

    # axetas = plot_etas_model(sip_true_inv[i], taus_cmb[i],
    #          ax=axetas, color="C2", label="Rec",
    #          linestyle=":", marker='.', markersize=3)
    axrm[0].invert_xaxis()
    axrm[0].set_xlim([1.2,0.09])
    axrm[1].set_xlim(right=0.5)
    axrm[0].set_title(fr"{title_head}_$\rho_0$ (ohm-m)")
    axrm[1].set_title(fr"{title_head}_$\sum\eta_k$ vs $\eta$")
    axetas.set_title(fr"{title_head} - $\eta_k$ vs $\tau_k$")
    axetas.set_xlim([1e-4,1.2e-1])
    axetas.set_ylim([0,0.1])
    for j , a in enumerate(axrm):  # Iterate over rows
        a.axhline(empymod_model_sim["src"][4], color=f"C4", linestyle="-", label="Src+Rec")
        a.set_ylim([12.5, -2.5])
        a.set_ylabel('depth [m]')
        if j== 0:
            a.set_xscale("log")
        else:
            a.set_xscale("linear")
    for a in (ax_range):
        a.legend()
\
# plt.savefig('43_Recovered_pelton.jpg')

# %% [markdown]
# save into jsonfile
